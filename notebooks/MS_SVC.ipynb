# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

sys.path.append('../src/')
from TrainModels import *

# %%
## Non GWAS Datasets

datasets_full = ['dataset_1_', 'dataset_2_', 'dataset_3_', 'dataset_7_']
datasets_gwas = []

feature_selection = {"method" : "Select From Model" , "estimator" : "SVC" }
train_models = ["all"]

TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 623
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'hamming', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8411588411588411
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8145562770562771, (0.7055529499677475, 0.9235596041448066))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7378819791319791, (0.6395448947804689, 0.8362190634834892))
# --> Test accuracy(confidence interval 0.95):(0.7526315789473683, (0.6692889466358581, 0.8359742112588785))
# --> Test f1(confidence interval 0.95):(0.6785497835497836, (0.5713916223529153, 0.7857079447466518))
# --> Test recall(confidence interval 0.95):(0.8436904761904762, (0.7566773596387496, 0.9307035927422028))
# --> Test precision(confidence interval 0.95):(0.6598809523809523, (0.5407259069417294, 0.7790359978201753))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9255594405594406
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9306060606060607, (0.8698951460290433, 0.991316975183078))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8987824675324676, (0.8684384299270654, 0.9291265051378698))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210527, (0.7919070529066924, 0.965987683935413))
# --> Test f1(confidence interval 0.95):(0.7666833312885946, (0.6794274599449542, 0.8539392026322349))
# --> Test recall(confidence interval 0.95):(0.9690476190476189, (0.9221958725287351, 1.0158993655665027))
# --> Test precision(confidence interval 0.95):(0.7224281274281273, (0.6461274117596287, 0.798728843096626))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9326673326673326
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9426082251082251, (0.9128841017724367, 0.9723323484440134))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8504030691530693, (0.8020816440327153, 0.8987244942734233))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.8432290974304053, 0.9146656394116999))
# --> Test f1(confidence interval 0.95):(0.8714799721449339, (0.8301590549234362, 0.9128008893664316))
# --> Test recall(confidence interval 0.95):(0.9360317460317461, (0.8671412623145134, 1.0049222297489788))
# --> Test precision(confidence interval 0.95):(0.7090476190476191, (0.5878828099663735, 0.8302124281288648))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9412837162837164
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9387440337440337, (0.9090704191101084, 0.968417648377959))
# --> Test balanced_accuracy(confidence interval 0.95):(0.864278083028083, (0.8088898878186891, 0.9196662782374768))
# --> Test accuracy(confidence interval 0.95):(0.8157894736842106, (0.746479164189612, 0.8850997831788092))
# --> Test f1(confidence interval 0.95):(0.8682565289214905, (0.7912443718027738, 0.9452686860402072))
# --> Test recall(confidence interval 0.95):(0.8822222222222222, (0.7675151624748258, 0.9969292819696187))
# --> Test precision(confidence interval 0.95):(0.7221031746031745, (0.5931257223265689, 0.8510806268797801))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 400}
# Best CV auc_roc: 0.9007192807192806
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.922967587967588, (0.8729923878520306, 0.9729427880831455))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8336950549450549, (0.7696012341763281, 0.8977888757137817))
# --> Test accuracy(confidence interval 0.95):(0.8263157894736842, (0.7864308804895181, 0.8662006984578503))
# --> Test f1(confidence interval 0.95):(0.8115923760808672, (0.7038823092162935, 0.919302442945441))
# --> Test recall(confidence interval 0.95):(0.9464285714285715, (0.8812925210243657, 1.0115646218327774))
# --> Test precision(confidence interval 0.95):(0.8723809523809523, (0.7958454354648747, 0.9489164692970298))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 300, 'subsample': 1.0}
# Best CV auc_roc: 0.8843806193806193
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9072619047619048, (0.8662436762703117, 0.9482801332534979))
# --> Test balanced_accuracy(confidence interval 0.95):(0.844249777999778, (0.7955703795998756, 0.8929291763996803))
# --> Test accuracy(confidence interval 0.95):(0.8157894736842104, (0.7714180948098516, 0.8601608525585692))
# --> Test f1(confidence interval 0.95):(0.8462293277757673, (0.7578998546917723, 0.9345588008597623))
# --> Test recall(confidence interval 0.95):(0.8190873015873015, (0.7357137445043825, 0.9024608586702204))
# --> Test precision(confidence interval 0.95):(0.6919588744588745, (0.5934306791614727, 0.7904870697562763))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9070979020979021
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8911849261849263, (0.83504988568001, 0.9473199666898425))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9210064935064934, (0.8729267230818694, 0.9690862639311175))
# --> Test accuracy(confidence interval 0.95):(0.8842105263157896, (0.8232422495733387, 0.9451788030582404))
# --> Test f1(confidence interval 0.95):(0.879744327373618, (0.8231149834623507, 0.9363736712848852))
# --> Test recall(confidence interval 0.95):(0.9095238095238095, (0.8332496440441176, 0.9857979750035014))
# --> Test precision(confidence interval 0.95):(0.8511507936507936, (0.7776533414678808, 0.9246482458337064))
# ----------------Training dataset_2_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 542
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 19, 'weights': 'distance'}
# Best CV auc_roc: 0.8166228070175441
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8389799253034548, (0.7579759490476088, 0.9199839015593008))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9012813897488818, (0.8449700518780939, 0.9575927276196697))
# --> Test accuracy(confidence interval 0.95):(0.8473684210526315, (0.7776050981769269, 0.9171317439283362))
# --> Test f1(confidence interval 0.95):(0.20666666666666664, (0.01041979437446991, 0.4029135389588634))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.5195238095238095, (0.29154694383975654, 0.7475006752078625))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.8878508771929825
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8502561327561328, (0.7599005969078796, 0.9406116686043859))
# --> Test balanced_accuracy(confidence interval 0.95):(0.849892070863433, (0.7618906551256808, 0.9378934866011852))
# --> Test accuracy(confidence interval 0.95):(0.8894736842105264, (0.8378806261129249, 0.9410667423081279))
# --> Test f1(confidence interval 0.95):(0.41833333333333333, (0.15373065478835274, 0.6829360118783139))
# --> Test recall(confidence interval 0.95):(0.9, (0.7491895224839339, 1.050810477516066))
# --> Test precision(confidence interval 0.95):(0.4083333333333333, (0.17583384716273145, 0.6408328195039352))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.917923976608187
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.919107142857143, (0.8542244435612399, 0.9839898421530461))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8165080593640965, (0.6980476201691734, 0.9349684985590196))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8260598492054527, 0.9213085718471787))
# --> Test f1(confidence interval 0.95):(0.6505050505050505, (0.452446101308687, 0.8485639997014139))
# --> Test recall(confidence interval 0.95):(0.7366666666666667, (0.4996893826267673, 0.9736439507065661))
# --> Test precision(confidence interval 0.95):(0.525, (0.30363642290739645, 0.7463635770926036))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9455555555555556
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9047074738986502, (0.797514487205578, 1.0119004605917223))
# --> Test balanced_accuracy(confidence interval 0.95):(0.848304244774833, (0.763025390608198, 0.9335830989414681))
# --> Test accuracy(confidence interval 0.95):(0.9473684210526315, (0.9222681787385062, 0.9724686633667569))
# --> Test f1(confidence interval 0.95):(0.7154761904761905, (0.4881500035996796, 0.9428023773527014))
# --> Test recall(confidence interval 0.95):(0.8266666666666665, (0.6864723945137507, 0.9668609388195823))
# --> Test precision(confidence interval 0.95):(0.7391666666666666, (0.5848351800214694, 0.8934981533118639))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.9201169590643274
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9226458019105077, (0.8662542486494776, 0.9790373551715378))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8105813553491572, (0.6777041488952448, 0.9434585618030696))
# --> Test accuracy(confidence interval 0.95):(0.9, (0.8454394398308046, 0.9545605601691954))
# --> Test f1(confidence interval 0.95):(0.42333333333333334, (0.18407430763253618, 0.6625923590341305))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.5700000000000001, (0.4361925828698822, 0.7038074171301179))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 50, 'n_estimators': 500, 'subsample': 0.6}
# Best CV auc_roc: 0.7951461988304094
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.5813725490196078, (0.4255286599003312, 0.7372164381388844))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8972824217406259, (0.8048133622060687, 0.9897514812751831))
# --> Test accuracy(confidence interval 0.95):(0.8263157894736842, (0.762199530836842, 0.8904320481105265))
# --> Test f1(confidence interval 0.95):(0.2246031746031746, (0.032723203700688125, 0.4164831455056611))
# --> Test recall(confidence interval 0.95):(0.825, (0.585803695265647, 1.0641963047343528))
# --> Test precision(confidence interval 0.95):(0.41, (0.15964400841774795, 0.660355991582252))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.89796783625731
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.91284165181224, (0.823813620733399, 1.001869682891081))
# --> Test balanced_accuracy(confidence interval 0.95):(0.845387641898865, (0.7939518991717696, 0.8968233846259603))
# --> Test accuracy(confidence interval 0.95):(0.8421052631578947, (0.7986303681875394, 0.88558015812825))
# --> Test f1(confidence interval 0.95):(0.45777777777777773, (0.20420813186843906, 0.7113474236871165))
# --> Test recall(confidence interval 0.95):(0.7666666666666667, (0.5871662947574406, 0.9461670385758928))
# --> Test precision(confidence interval 0.95):(0.2566666666666667, (0.0922094716696446, 0.4211238616636888))
# ----------------Training dataset_3_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 849
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8276468894009217
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8468074224487268, (0.7765092040793005, 0.917105640818153))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7335361126460509, (0.6517679085798107, 0.8153043167122911))
# --> Test accuracy(confidence interval 0.95):(0.7842105263157895, (0.7282251687029873, 0.8401958839285917))
# --> Test f1(confidence interval 0.95):(0.5789653279371949, (0.43586956424542467, 0.7220610916289651))
# --> Test recall(confidence interval 0.95):(0.7349378399378399, (0.6271858564761639, 0.8426898233995159))
# --> Test precision(confidence interval 0.95):(0.5311632811632812, (0.4050252851183821, 0.6573012772081802))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9295132488479261
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8850055510930233, (0.8303200936166034, 0.9396910085694431))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8479786304126702, (0.7970193245432721, 0.8989379362820683))
# --> Test accuracy(confidence interval 0.95):(0.8921052631578947, (0.8491314051871148, 0.9350791211286746))
# --> Test f1(confidence interval 0.95):(0.8043399259017109, (0.7247702300702755, 0.8839096217331462))
# --> Test recall(confidence interval 0.95):(0.8020039682539682, (0.6871926258984296, 0.9168153106095069))
# --> Test precision(confidence interval 0.95):(0.7337012987012987, (0.6423360401586248, 0.8250665572439727))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9355184331797233
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.814496839367529, (0.742596663735265, 0.8863970149997931))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8420133821910797, (0.8160416186712464, 0.867985145710913))
# --> Test accuracy(confidence interval 0.95):(0.8473684210526315, (0.8040750504449077, 0.8906617916603554))
# --> Test f1(confidence interval 0.95):(0.7961078147794789, (0.7542499719541448, 0.837965657604813))
# --> Test recall(confidence interval 0.95):(0.7848884448884449, (0.6550429876209782, 0.9147339021559115))
# --> Test precision(confidence interval 0.95):(0.6867993117993118, (0.5928347907046132, 0.7807638328940103))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9454670698924732
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8629608507711957, (0.8237811221684539, 0.9021405793739374))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8526480696914994, (0.8220710736590718, 0.883225065723927))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8332112859100701, 0.9141571351425614))
# --> Test f1(confidence interval 0.95):(0.7441167312219943, (0.6470197182042025, 0.8412137442397861))
# --> Test recall(confidence interval 0.95):(0.8087798312798313, (0.7178427818790009, 0.8997168806806618))
# --> Test precision(confidence interval 0.95):(0.7376334776334776, (0.6756557013777225, 0.7996112538892328))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.9213695276497695
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8738551968465762, (0.836554657038696, 0.9111557366544564))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8288811170161976, (0.7836990503489478, 0.8740631836834474))
# --> Test accuracy(confidence interval 0.95):(0.8447368421052632, (0.8046058795288767, 0.8848678046816497))
# --> Test f1(confidence interval 0.95):(0.6556886476156254, (0.5731624172320338, 0.738214877999217))
# --> Test recall(confidence interval 0.95):(0.7701903651903652, (0.6449119724031267, 0.8954687579776037))
# --> Test precision(confidence interval 0.95):(0.6642442279942281, (0.5658256009476126, 0.7626628550408436))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 300, 'subsample': 1.0}
# Best CV auc_roc: 0.9284418202764977
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8733450843121009, (0.8084474278823213, 0.9382427407418805))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8404380255689962, (0.796058280218543, 0.8848177709194494))
# --> Test accuracy(confidence interval 0.95):(0.8026315789473684, (0.7378736834392425, 0.8673894744554942))
# --> Test f1(confidence interval 0.95):(0.7881063833162784, (0.721497600120304, 0.8547151665122528))
# --> Test recall(confidence interval 0.95):(0.7783222496457791, (0.6735828695082823, 0.883061629783276))
# --> Test precision(confidence interval 0.95):(0.70009324009324, (0.6324019261870184, 0.7677845539994617))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9304068260368663
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9028868169422892, (0.8542923563569822, 0.9514812775275963))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8203733881061467, (0.7847370636681776, 0.8560097125441157))
# --> Test accuracy(confidence interval 0.95):(0.8657894736842107, (0.8168198722707614, 0.91475907509766))
# --> Test f1(confidence interval 0.95):(0.6395590470910164, (0.5420291582024606, 0.7370889359795723))
# --> Test recall(confidence interval 0.95):(0.7900388500388501, (0.6827552956140255, 0.8973224044636747))
# --> Test precision(confidence interval 0.95):(0.675357142857143, (0.5891198557495423, 0.7615944299647437))
# ----------------Training dataset_7_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 607
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8266133866133867
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8780952380952382, (0.8198584766096765, 0.9363319995807998))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7257933406462819, (0.6703319891441996, 0.7812546921483642))
# --> Test accuracy(confidence interval 0.95):(0.7421052631578948, (0.6701196236124013, 0.8140909027033884))
# --> Test f1(confidence interval 0.95):(0.6426606288448393, (0.549456536566664, 0.7358647211230146))
# --> Test recall(confidence interval 0.95):(0.773968253968254, (0.6989535919818979, 0.8489829159546101))
# --> Test precision(confidence interval 0.95):(0.6281138306138306, (0.5239281645533028, 0.7322994966743585))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9358291708291707
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9403268953268954, (0.8887479864378963, 0.9919058042158945))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7702372627372627, (0.7147626609046659, 0.8257118645698595))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.748533290360885, 0.8725193412180623))
# --> Test f1(confidence interval 0.95):(0.7275108225108224, (0.6386375529414258, 0.8163840920802191))
# --> Test recall(confidence interval 0.95):(0.9440476190476191, (0.8768652955718714, 1.0112299425233668))
# --> Test precision(confidence interval 0.95):(0.7531746031746032, (0.6410159053275944, 0.8653333010216119))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9523676323676323
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9087651237651239, (0.8381477582431901, 0.9793824892870576))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8810479797979799, (0.8283731204811806, 0.9337228391147792))
# --> Test accuracy(confidence interval 0.95):(0.9526315789473683, (0.9151909684367626, 0.9900721894579739))
# --> Test f1(confidence interval 0.95):(0.9138059163059162, (0.8730699297507574, 0.9545419028610751))
# --> Test recall(confidence interval 0.95):(0.8261868686868687, (0.7466845208003873, 0.9056892165733502))
# --> Test precision(confidence interval 0.95):(0.9816666666666667, (0.9538756331120376, 1.0094577002212957))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.001, 'gamma': 1, 'kernel': 'poly'}
# Best CV auc_roc: 0.953921078921079
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9407936507936508, (0.8665577196036799, 1.015029581983622))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8979738317238317, (0.8524038113249363, 0.9435438521227272))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842105, (0.8681651123633475, 0.9634138350050735))
# --> Test f1(confidence interval 0.95):(0.8549636637871932, (0.7960332934186899, 0.9138940341556966))
# --> Test recall(confidence interval 0.95):(0.8107936507936507, (0.7494521167111652, 0.8721351848761363))
# --> Test precision(confidence interval 0.95):(0.8770562770562771, (0.7832452415391313, 0.9708673125734228))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.9243856143856144
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9709726384726386, (0.949172796747001, 0.9927724801982762))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8911258186258186, (0.8685064864916979, 0.9137451507599393))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210527, (0.8285902516348731, 0.9293044852072323))
# --> Test f1(confidence interval 0.95):(0.8269957983193278, (0.77096079013258, 0.8830308065060756))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.7998629148629148, (0.731473768260871, 0.8682520614649587))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 100, 'subsample': 0.8}
# Best CV auc_roc: 0.9271578421578421
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9014763014763016, (0.8319116163747587, 0.9710409865778445))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8473737373737373, (0.785445840203221, 0.9093016345442537))
# --> Test accuracy(confidence interval 0.95):(0.9105263157894736, (0.8668706512453492, 0.954181980333598))
# --> Test f1(confidence interval 0.95):(0.890824549846289, (0.8126015834962601, 0.9690475161963179))
# --> Test recall(confidence interval 0.95):(0.8059090909090909, (0.676968245248163, 0.9348499365700188))
# --> Test precision(confidence interval 0.95):(0.8751839826839827, (0.8184362114291072, 0.9319317539388582))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9441158841158842
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9113594738594738, (0.8444239351164942, 0.9782950126024534))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8773010323010324, (0.8215839967969109, 0.933018067805154))
# --> Test accuracy(confidence interval 0.95):(0.8842105263157893, (0.8346415194618241, 0.9337795331697546))
# --> Test f1(confidence interval 0.95):(0.8686454819690115, (0.8252253271880655, 0.9120656367499574))
# --> Test recall(confidence interval 0.95):(0.8586111111111112, (0.7273805781581962, 0.9898416440640262))
# --> Test precision(confidence interval 0.95):(0.8940501165501166, (0.7859992184239903, 1.0021010146762428))

# %%
## GWAS Datasets

sys.path.append('../src/')
from TrainModels import *

datasets_full = []
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

feature_selection = {"method" : "Select From Model" , "estimator" : "SVC" }
train_models = ["all"]

TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# GWAS datasets #############################
# ----------------Training dataset_19_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 610
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'hamming', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8247002997002998
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.848626651126651, (0.7946444896426889, 0.9026088126106132))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7327415639915639, (0.6278223360077975, 0.8376607919753303))
# --> Test accuracy(confidence interval 0.95):(0.7894736842105263, (0.7230646851998903, 0.8558826832211623))
# --> Test f1(confidence interval 0.95):(0.7050466853408031, (0.5699495376175888, 0.8401438330640173))
# --> Test recall(confidence interval 0.95):(0.724484126984127, (0.6103442852810348, 0.8386239686872192))
# --> Test precision(confidence interval 0.95):(0.5958333333333334, (0.5080540183680049, 0.683612648298662))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9047752247752248
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8762373737373738, (0.8163787456937943, 0.9360960017809532))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8705351592851592, (0.8258654254239235, 0.915204893146395))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.828590251634873, 0.9293044852072322))
# --> Test f1(confidence interval 0.95):(0.7847693972693972, (0.7073289166478609, 0.8622098778909335))
# --> Test recall(confidence interval 0.95):(0.8236904761904762, (0.7461228542257256, 0.9012580981552268))
# --> Test precision(confidence interval 0.95):(0.7594011544011543, (0.6503620501075861, 0.8684402586947225))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9206943056943058
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9213517038517038, (0.8826263426160206, 0.9600770650873871))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7973412698412699, (0.7098011975387895, 0.8848813421437502))
# --> Test accuracy(confidence interval 0.95):(0.8631578947368421, (0.8011648693082536, 0.9251509201654307))
# --> Test f1(confidence interval 0.95):(0.7445954535660417, (0.6408786136644051, 0.8483122934676783))
# --> Test recall(confidence interval 0.95):(0.861504329004329, (0.7907920629045226, 0.9322165951041355))
# --> Test precision(confidence interval 0.95):(0.701031746031746, (0.5712019769507747, 0.8308615151127173))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# Best CV auc_roc: 0.9275624375624376
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9028732378732378, (0.8555178859999315, 0.9502285897465441))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8489269064269067, (0.7712765882558897, 0.9265772245979237))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421052, (0.8180098278579391, 0.8977796458262712))
# --> Test f1(confidence interval 0.95):(0.8902008971420736, (0.8257208496574725, 0.9546809446266747))
# --> Test recall(confidence interval 0.95):(0.8499475524475525, (0.7597270924060759, 0.940168012489029))
# --> Test precision(confidence interval 0.95):(0.8112121212121212, (0.682511028380109, 0.9399132140441333))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV auc_roc: 0.9031968031968031
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8819942557442557, (0.8112369021616151, 0.9527516093268963))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8082203907203909, (0.7479910959678098, 0.868449685472972))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.753841987818139, 0.8672106437608083))
# --> Test f1(confidence interval 0.95):(0.8159353588186541, (0.7540916862304083, 0.8777790314068998))
# --> Test recall(confidence interval 0.95):(0.6753174603174603, (0.5846120652247264, 0.7660228554101942))
# --> Test precision(confidence interval 0.95):(0.7313852813852815, (0.651868774630971, 0.8109017881395919))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 300, 'subsample': 0.8}
# Best CV auc_roc: 0.884090909090909
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8754567654567655, (0.7936652147089885, 0.9572483162045425))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7366663565192978, (0.6475531128221305, 0.8257796002164651))
# --> Test accuracy(confidence interval 0.95):(0.7789473684210526, (0.7083982713510002, 0.849496465491105))
# --> Test f1(confidence interval 0.95):(0.6800870044987691, (0.5951363598760587, 0.7650376491214795))
# --> Test recall(confidence interval 0.95):(0.8183730158730158, (0.7604483223091092, 0.8762977094369224))
# --> Test precision(confidence interval 0.95):(0.6272619047619048, (0.5346949316904948, 0.7198288778333148))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6}
# Best CV auc_roc: 0.9071828171828173
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8247420634920635, (0.7344393314399358, 0.9150447955441912))
# --> Test balanced_accuracy(confidence interval 0.95):(0.800835137085137, (0.7417783260457601, 0.8598919481245139))
# --> Test accuracy(confidence interval 0.95):(0.7842105263157895, (0.7357664083885469, 0.832654644243032))
# --> Test f1(confidence interval 0.95):(0.7657879547353231, (0.6911890375823827, 0.8403868718882636))
# --> Test recall(confidence interval 0.95):(0.717564935064935, (0.585575544922723, 0.849554325207147))
# --> Test precision(confidence interval 0.95):(0.6765079365079365, (0.6026424826101002, 0.7503733904057728))
# ----------------Training dataset_20_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 606
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 19, 'weights': 'distance'}
# Best CV auc_roc: 0.8226754385964912
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8012278244631187, (0.7520167372860066, 0.8504389116402308))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8758771929824561, (0.8061256300183155, 0.9456287559465968))
# --> Test accuracy(confidence interval 0.95):(0.8368421052631578, (0.7794673215329311, 0.8942168889933846))
# --> Test f1(confidence interval 0.95):(0.15666666666666668, (-0.02941781870444063, 0.34275115203777395))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.05928571428571429, (-0.011354227335154413, 0.129925655906583))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9348245614035088
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8970833333333333, (0.7994111298979832, 0.9947555367686834))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9581355349157207, (0.93428491093469, 0.9819861588967513))
# --> Test accuracy(confidence interval 0.95):(0.9052631578947368, (0.8526124454341978, 0.9579138703552758))
# --> Test f1(confidence interval 0.95):(0.7228571428571428, (0.5902353544280321, 0.8554789312862534))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.7166666666666666, (0.5407211095645894, 0.8926122237687437))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.951593567251462
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8772023809523809, (0.7715726911337081, 0.9828320707710537))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9589385534915721, (0.9335122751101531, 0.9843648318729911))
# --> Test accuracy(confidence interval 0.95):(0.9, (0.8399427199233581, 0.9600572800766419))
# --> Test f1(confidence interval 0.95):(0.7201515151515152, (0.5057963699562692, 0.9345066603467612))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.48273809523809524, (0.2620773946903454, 0.7033987957858451))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9572953216374269
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8593137254901961, (0.7389401126506147, 0.9796873383297776))
# --> Test balanced_accuracy(confidence interval 0.95):(0.93765479876161, (0.9051585977726809, 0.970150999750539))
# --> Test accuracy(confidence interval 0.95):(0.9263157894736842, (0.8786914281528212, 0.9739401507945472))
# --> Test f1(confidence interval 0.95):(0.7978932178932179, (0.5840736801450519, 1.0117127556413839))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.4504761904761905, (0.16190960586464792, 0.7390427750877331))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.926812865497076
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9423809523809524, (0.8888507645776845, 0.9959111401842203))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8968094255245959, (0.8569203916132991, 0.9366984594358926))
# --> Test accuracy(confidence interval 0.95):(0.8526315789473685, (0.7798841653884413, 0.9253789925062957))
# --> Test f1(confidence interval 0.95):(0.33999999999999997, (0.1218020281122684, 0.5581979718877316))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.32333333333333336, (0.09633698372425048, 0.5503296829424162))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 50, 'n_estimators': 500, 'subsample': 1.0}
# Best CV auc_roc: 0.7748830409356724
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.5182296380090498, (0.30355812899466955, 0.7329011470234299))
# --> Test balanced_accuracy(confidence interval 0.95):(0.906045966632267, (0.8328607536351165, 0.9792311796294175))
# --> Test accuracy(confidence interval 0.95):(0.8526315789473683, (0.8063490189665877, 0.8989141389281489))
# --> Test f1(confidence interval 0.95):(0.3761904761904762, (0.15286581439118438, 0.599515137989768))
# --> Test recall(confidence interval 0.95):(0.9, (0.6737842837259009, 1.126215716274099))
# --> Test precision(confidence interval 0.95):(0.4116666666666666, (0.18447210185926463, 0.6388612314740686))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.929795321637427
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9019397759103642, (0.762990482131197, 1.0408890696895314))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9181841245270039, (0.8824519068647841, 0.9539163421892237))
# --> Test accuracy(confidence interval 0.95):(0.8421052631578947, (0.7859794150917938, 0.8982311112239956))
# --> Test f1(confidence interval 0.95):(0.4602380952380953, (0.21075364725621115, 0.7097225432199794))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.5449999999999999, (0.32286717877548476, 0.7671328212245151))
# ----------------Training dataset_21_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 906
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8499901593701997
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8500446919356655, (0.7922490035318195, 0.9078403803395114))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7792004726826751, (0.7329825313923602, 0.82541841397299))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894738, (0.7672329451817499, 0.8538196863971976))
# --> Test f1(confidence interval 0.95):(0.658781512605042, (0.5922598756117099, 0.7253031495983742))
# --> Test recall(confidence interval 0.95):(0.6687770562770563, (0.48607375733512803, 0.8514803552189846))
# --> Test precision(confidence interval 0.95):(0.5932371794871794, (0.499099106299797, 0.6873752526745618))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9202270545314899
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9283968296196559, (0.8981563139019252, 0.9586373453373865))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8928791522343786, (0.8578339997345437, 0.9279243047342136))
# --> Test accuracy(confidence interval 0.95):(0.85, (0.8092845751634049, 0.890715424836595))
# --> Test f1(confidence interval 0.95):(0.7278737194178372, (0.6582142474227038, 0.7975331914129705))
# --> Test recall(confidence interval 0.95):(0.7864610389610389, (0.6869224309145732, 0.8859996470075047))
# --> Test precision(confidence interval 0.95):(0.8965312465312467, (0.8230121573911822, 0.9700503356713113))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9301248079877112
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9478922715936065, (0.9130736840140474, 0.9827108591731655))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8716353971074735, (0.8342514554234894, 0.9090193387914576))
# --> Test accuracy(confidence interval 0.95):(0.9026315789473683, (0.8705734496289472, 0.9346897082657895))
# --> Test f1(confidence interval 0.95):(0.8201754681428003, (0.7790916363613359, 0.8612592999242646))
# --> Test recall(confidence interval 0.95):(0.7654567654567656, (0.6673610523450791, 0.863552478568452))
# --> Test precision(confidence interval 0.95):(0.9025518925518925, (0.8461713651146836, 0.9589324199891014))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# Best CV auc_roc: 0.9333107718894009
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9335032844992522, (0.8908805486475583, 0.9761260203509462))
# --> Test balanced_accuracy(confidence interval 0.95):(0.835626826396167, (0.7910419981537438, 0.8802116546385903))
# --> Test accuracy(confidence interval 0.95):(0.8605263157894736, (0.8207897702791258, 0.9002628612998214))
# --> Test f1(confidence interval 0.95):(0.7572257289227836, (0.6787215613063311, 0.8357298965392361))
# --> Test recall(confidence interval 0.95):(0.8475201088900779, (0.7721807929456052, 0.9228594248345506))
# --> Test precision(confidence interval 0.95):(0.7898426573426574, (0.7246159413053198, 0.8550693733799949))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.9248612711213517
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9285680973952262, (0.8983737328319519, 0.9587624619585005))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8709764389505767, (0.840249504994443, 0.9017033729067105))
# --> Test accuracy(confidence interval 0.95):(0.8526315789473685, (0.8272195204252121, 0.878043637469525))
# --> Test f1(confidence interval 0.95):(0.7737901677702437, (0.6598872148020343, 0.8876931207384531))
# --> Test recall(confidence interval 0.95):(0.8335317460317458, (0.7514527821331141, 0.9156107099303776))
# --> Test precision(confidence interval 0.95):(0.8243226952785777, (0.7374143601144778, 0.9112310304426776))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.01, 'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 400, 'subsample': 1.0}
# Best CV auc_roc: 0.8987240783410136
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8687094656551178, (0.8195687309937121, 0.9178502003165234))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8668851682964587, (0.8079800148648406, 0.9257903217280767))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.7672329451817498, 0.8538196863971975))
# --> Test f1(confidence interval 0.95):(0.7803530262840608, (0.7050894866055999, 0.8556165659625217))
# --> Test recall(confidence interval 0.95):(0.8097283272283272, (0.7165803866241179, 0.9028762678325365))
# --> Test precision(confidence interval 0.95):(0.6011201298701299, (0.47951582697700834, 0.7227244327632514))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9151888920890936
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8962372963084169, (0.867219039144367, 0.9252555534724667))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7990093122907966, (0.728197684549155, 0.8698209400324383))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684211, (0.7852963873876405, 0.8778615073492017))
# --> Test f1(confidence interval 0.95):(0.6514612857192612, (0.5514959416245228, 0.7514266298139997))
# --> Test recall(confidence interval 0.95):(0.7345337995337995, (0.6025398808593012, 0.8665277182082978))
# --> Test precision(confidence interval 0.95):(0.6875044563279856, (0.568172753604424, 0.8068361590515473))
