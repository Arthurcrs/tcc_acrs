# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8088836163836165
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8055486180486181, (0.735715257910278, 0.8753819781869582))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7395088245088244, (0.6457509474809913, 0.8332667015366575))
# --> Test accuracy(confidence interval 0.95):(0.7421052631578948, (0.7006708523678187, 0.783539673947971))
# --> Test f1(confidence interval 0.95):(0.652643745143745, (0.5288596815909625, 0.7764278086965275))
# --> Test recall(confidence interval 0.95):(0.7380844155844156, (0.6336600265175936, 0.8425088046512377))
# --> Test precision(confidence interval 0.95):(0.5623737373737374, (0.4408192211544296, 0.6839282535930452))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8704145854145855
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8915064102564102, (0.8339797654711412, 0.9490330550416792))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8746374458874457, (0.8198443649952339, 0.9294305267796575))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421053, (0.8142390722979809, 0.9015504013862297))
# --> Test f1(confidence interval 0.95):(0.8782925407925408, (0.8063387377310527, 0.950246343854029))
# --> Test recall(confidence interval 0.95):(0.8733333333333334, (0.7942576379218665, 0.9524090287448003))
# --> Test precision(confidence interval 0.95):(0.8736507936507938, (0.7821718944240417, 0.9651296928775459))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.8764885114885115
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9137265512265513, (0.8596630467028432, 0.9677900557502594))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8922557303807302, (0.818784045171267, 0.9657274155901935))
# --> Test accuracy(confidence interval 0.95):(0.8421052631578947, (0.8024182953905089, 0.8817922309252805))
# --> Test f1(confidence interval 0.95):(0.8720859841912473, (0.8085524419654851, 0.9356195264170094))
# --> Test recall(confidence interval 0.95):(0.9436507936507936, (0.8907662591821958, 0.9965353281193915))
# --> Test precision(confidence interval 0.95):(0.785, (0.7162910634833144, 0.8537089365166857))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.1, 'gamma': 0.1, 'kernel': 'poly'}
# Best CV auc_roc: 0.8826873126873126
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.928415195915196, (0.8830497800605533, 0.9737806117698385))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8282595182595183, (0.7587346173283496, 0.897784419190687))
# --> Test accuracy(confidence interval 0.95):(0.8631578947368421, (0.8226849701205965, 0.9036308193530878))
# --> Test f1(confidence interval 0.95):(0.8604565334905893, (0.8139317837359697, 0.9069812832452088))
# --> Test recall(confidence interval 0.95):(0.8373304473304473, (0.74574484051442, 0.9289160541464745))
# --> Test precision(confidence interval 0.95):(0.82757215007215, (0.7603559117946902, 0.8947883883496098))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.8578821178821178
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9056242368742369, (0.8602620304308373, 0.9509864433176365))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8326641414141415, (0.7789147948762537, 0.8864134879520292))
# --> Test accuracy(confidence interval 0.95):(0.8210526315789475, (0.7518560388295111, 0.8902492243283838))
# --> Test f1(confidence interval 0.95):(0.7848715663421546, (0.7100876733080622, 0.859655459376247))
# --> Test recall(confidence interval 0.95):(0.937936507936508, (0.8785562111969488, 0.9973168046760671))
# --> Test precision(confidence interval 0.95):(0.6778030303030302, (0.5998255216246781, 0.7557805389813824))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 400, 'subsample': 1.0}
# Best CV auc_roc: 0.8741358641358641
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9031529581529583, (0.8227458619664775, 0.983560054339439))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8997030747030748, (0.8580526374527795, 0.94135351195337))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.831821705254334, 0.9260730315877712))
# --> Test f1(confidence interval 0.95):(0.8239085914085914, (0.7479111801936587, 0.8999060026235242))
# --> Test recall(confidence interval 0.95):(0.8798809523809524, (0.8272135674066591, 0.9325483373552458))
# --> Test precision(confidence interval 0.95):(0.7207611832611833, (0.6248897850665116, 0.816632581455855))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9002772227772228
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9035475635475635, (0.8117007493266619, 0.9953943777684651))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9021700521700522, (0.8607492166829972, 0.9435908876571072))
# --> Test accuracy(confidence interval 0.95):(0.9315789473684211, (0.8958606763777739, 0.9672972183590682))
# --> Test f1(confidence interval 0.95):(0.8436243714294317, (0.7531979191849563, 0.9340508236739071))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.8548304473304473, (0.7539566213761271, 0.9557042732847676))
# ----------------Training dataset_2_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 11, 'weights': 'distance'}
# Best CV auc_roc: 0.769985380116959
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.808295985060691, (0.6589053346754881, 0.9576866354458939))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8117217062263503, (0.6610634645051762, 0.9623799479475245))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8294906735655089, 0.9178777474871226))
# --> Test f1(confidence interval 0.95):(0.4966666666666667, (0.23534644187303694, 0.7579868914602965))
# --> Test recall(confidence interval 0.95):(0.9, (0.6737842837259009, 1.126215716274099))
# --> Test precision(confidence interval 0.95):(0.2766666666666667, (0.10277986806897604, 0.4505534652643574))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8388669590643275
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7714786235006824, (0.6410012914115195, 0.9019559555898453))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7458376332989337, (0.6168166668351398, 0.8748585997627276))
# --> Test accuracy(confidence interval 0.95):(0.8421052631578949, (0.7832399770951147, 0.9009705492206751))
# --> Test f1(confidence interval 0.95):(0.26666666666666666, (-0.004046425355556216, 0.5373797586888895))
# --> Test recall(confidence interval 0.95):(0.8133333333333332, (0.5591829991504096, 1.067483667516257))
# --> Test precision(confidence interval 0.95):(0.38666666666666666, (0.2271232463157011, 0.5462100870176322))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.8674853801169592
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9071218487394959, (0.8232583713293423, 0.9909853261496494))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7639787581699347, (0.6209931319686861, 0.9069643843711832))
# --> Test accuracy(confidence interval 0.95):(0.8894736842105262, (0.8410295662832836, 0.9379178021377688))
# --> Test f1(confidence interval 0.95):(0.5678860028860029, (0.3923296234261179, 0.7434423823458879))
# --> Test recall(confidence interval 0.95):(0.7416666666666666, (0.5305282578380802, 0.952805075495253))
# --> Test precision(confidence interval 0.95):(0.6014285714285714, (0.4626754795138021, 0.7401816633433407))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9055847953216375
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8643500127323657, (0.782571096571864, 0.9461289288928674))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7964532159017453, (0.6926348062857769, 0.9002716255177138))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.8199484493007955, 0.9379462875413097))
# --> Test f1(confidence interval 0.95):(0.6957142857142856, (0.4943888592404594, 0.8970397121881118))
# --> Test recall(confidence interval 0.95):(0.6849999999999999, (0.5121837607633494, 0.8578162392366505))
# --> Test precision(confidence interval 0.95):(0.7266666666666667, (0.5005766607197382, 0.9527566726135952))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.869122807017544
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8786685128596894, (0.7929389713622764, 0.9643980543571024))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9271435328517372, (0.8881599255526696, 0.9661271401508048))
# --> Test accuracy(confidence interval 0.95):(0.9105263157894739, (0.8795298030751796, 0.9415228285037681))
# --> Test f1(confidence interval 0.95):(0.49984126984126986, (0.26630208162808755, 0.7333804580544522))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.345, (0.1454925323311022, 0.5445074676688977))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 50, 'n_estimators': 300, 'subsample': 0.6}
# Best CV auc_roc: 0.7934649122807017
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.6193177655677655, (0.4951531848147023, 0.7434823463208288))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9152820777433781, (0.8800183120804791, 0.9505458434062771))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.831821705254334, 0.9260730315877712))
# --> Test f1(confidence interval 0.95):(0.2388095238095238, (0.009699770897652088, 0.46791927672139555))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.21428571428571427, (0.07832327734126937, 0.3502481512301592))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 1.0, 'gamma': 1.5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.6}
# Best CV auc_roc: 0.8907894736842106
# Best estimator metrics:
# error roc_auc
# --> Test roc_auc(confidence interval 0.95):(0.8348529411764707, (0.715953126190973, 0.9537527561619684))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8102754435107377, (0.6800464725546003, 0.940504414466875))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421053, (0.8107690736753865, 0.905020400008824))
# --> Test f1(confidence interval 0.95):(0.5255555555555556, (0.3179462899839979, 0.7331648211271132))
# --> Test recall(confidence interval 0.95):(0.6666666666666666, (0.46995355365700897, 0.8633797796763243))
# --> Test precision(confidence interval 0.95):(0.5333333333333333, (0.33225269664524515, 0.7344139700214215))
# ----------------Training dataset_3_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8157061251920122
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7689281407063666, (0.6957284260500294, 0.8421278553627038))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7496725313972163, (0.7029942789573275, 0.7963507838371052))
# --> Test accuracy(confidence interval 0.95):(0.7552631578947369, (0.7099695637310276, 0.8005567520584461))
# --> Test f1(confidence interval 0.95):(0.5742194457701256, (0.4989150888796273, 0.6495238026606239))
# --> Test recall(confidence interval 0.95):(0.6726551226551226, (0.5740613217174656, 0.7712489235927796))
# --> Test precision(confidence interval 0.95):(0.467804286356918, (0.40713634974086504, 0.5284722229729709))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8966642665130568
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7972778656528656, (0.7284655770557895, 0.8660901542499417))
# --> Test balanced_accuracy(confidence interval 0.95):(0.824752123527699, (0.7820181411179364, 0.8674861059374616))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684211, (0.7789282349078821, 0.8842296598289601))
# --> Test f1(confidence interval 0.95):(0.6446615357822255, (0.5026550629921442, 0.7866680085723068))
# --> Test recall(confidence interval 0.95):(0.8335876623376623, (0.7144252710026802, 0.9527500536726445))
# --> Test precision(confidence interval 0.95):(0.7427718115218115, (0.6394330426777376, 0.8461105803658854))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9032042050691244
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8400907138838173, (0.8095656810359074, 0.8706157467317271))
# --> Test balanced_accuracy(confidence interval 0.95):(0.816969270512374, (0.7522997646140411, 0.8816387764107069))
# --> Test accuracy(confidence interval 0.95):(0.8657894736842104, (0.8066239376857023, 0.9249550096827186))
# --> Test f1(confidence interval 0.95):(0.6806470502122677, (0.5597208184963568, 0.8015732819281786))
# --> Test recall(confidence interval 0.95):(0.8368181818181819, (0.7422456165388039, 0.9313907470975599))
# --> Test precision(confidence interval 0.95):(0.7232962217521041, (0.6364287349166264, 0.8101637085875817))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.01, 'gamma': 0.1, 'kernel': 'poly'}
# Best CV auc_roc: 0.9203048195084484
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8380703281187152, (0.7985303772611667, 0.8776102789762636))
# --> Test balanced_accuracy(confidence interval 0.95):(0.815304602417244, (0.7669561292520102, 0.8636530755824778))
# --> Test accuracy(confidence interval 0.95):(0.8552631578947368, (0.8173522351659943, 0.8931740806234794))
# --> Test f1(confidence interval 0.95):(0.767063701194136, (0.6984437707309545, 0.8356836316573175))
# --> Test recall(confidence interval 0.95):(0.7160858585858586, (0.6055699308839707, 0.8266017862877465))
# --> Test precision(confidence interval 0.95):(0.6155759273406333, (0.5379859822183384, 0.6931658724629282))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.8923322292626729
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8691984784071229, (0.8220634519399643, 0.9163335048742816))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8165724050853361, (0.7390359422538386, 0.8941088679168336))
# --> Test accuracy(confidence interval 0.95):(0.8289473684210525, (0.7793386587118203, 0.8785560781302848))
# --> Test f1(confidence interval 0.95):(0.6454057366781825, (0.5645696705121769, 0.726241802844188))
# --> Test recall(confidence interval 0.95):(0.8544841269841269, (0.7610880509900636, 0.9478802029781902))
# --> Test precision(confidence interval 0.95):(0.49728506787330307, (0.40732166886492144, 0.5872484668816846))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 15, 'min_samples_leaf': 20, 'n_estimators': 100, 'subsample': 1.0}
# Best CV auc_roc: 0.9169170026881719
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8810704758204759, (0.8324467546885868, 0.9296941969523651))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8366484583990145, (0.7698803996425602, 0.9034165171554688))
# --> Test accuracy(confidence interval 0.95):(0.8131578947368421, (0.7641882933233928, 0.8621274961502914))
# --> Test f1(confidence interval 0.95):(0.6708232186493055, (0.6008404896517475, 0.7408059476468635))
# --> Test recall(confidence interval 0.95):(0.755540293040293, (0.634633923826695, 0.876446662253891))
# --> Test precision(confidence interval 0.95):(0.6140873015873015, (0.5180189621896371, 0.710155640984966))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.8}
# Best CV auc_roc: 0.9245653321812595
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8904425054927303, (0.8434454761287657, 0.9374395348566948))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8619391899453077, (0.8119426583629322, 0.9119357215276832))
# --> Test accuracy(confidence interval 0.95):(0.8526315789473685, (0.8055059157806499, 0.8997572421140871))
# --> Test f1(confidence interval 0.95):(0.7640957261692557, (0.7049487435958869, 0.8232427087426245))
# --> Test recall(confidence interval 0.95):(0.8353296703296703, (0.727256934528699, 0.9434024061306416))
# --> Test precision(confidence interval 0.95):(0.6910155122655123, (0.5734531464130794, 0.8085778781179451))
# ----------------Training dataset_7_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8128596403596404
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8193154068154069, (0.7538956182387602, 0.8847351953920537))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7521194083694085, (0.6671171273738372, 0.8371216893649798))
# --> Test accuracy(confidence interval 0.95):(0.7421052631578947, (0.6508252372929073, 0.8333852890228821))
# --> Test f1(confidence interval 0.95):(0.6224361912597207, (0.4824393203419694, 0.762433062177472))
# --> Test recall(confidence interval 0.95):(0.7041330891330891, (0.5705555293567635, 0.8377106489094148))
# --> Test precision(confidence interval 0.95):(0.6134090909090909, (0.5232583698722465, 0.7035598119459353))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.9141958041958042
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9064448051948052, (0.8668251575332399, 0.9460644528563705))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8881259018759019, (0.8391670122342405, 0.9370847915175633))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210527, (0.8285902516348731, 0.9293044852072323))
# --> Test f1(confidence interval 0.95):(0.8617843137254901, (0.7919004030098995, 0.9316682244410808))
# --> Test recall(confidence interval 0.95):(0.8758333333333332, (0.7943645534871938, 0.9573021131794727))
# --> Test precision(confidence interval 0.95):(0.8448809523809523, (0.7531731847283022, 0.9365887200336024))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9135114885114884
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9468903318903319, (0.8819338013915409, 1.011846862389123))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9040440115440116, (0.8474902078241754, 0.9605978152638478))
# --> Test accuracy(confidence interval 0.95):(0.8684210526315788, (0.8088906009805, 0.9279515042826575))
# --> Test f1(confidence interval 0.95):(0.8691317751063343, (0.8027665380554005, 0.9354970121572681))
# --> Test recall(confidence interval 0.95):(0.9690476190476189, (0.9221958725287351, 1.0158993655665027))
# --> Test precision(confidence interval 0.95):(0.9030905205905206, (0.8564609761428175, 0.9497200650382238))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.001, 'gamma': 1, 'kernel': 'poly'}
# Best CV auc_roc: 0.9124375624375626
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9551998001998001, (0.9207389365153787, 0.9896606638842215))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8653217615717615, (0.79856327694374, 0.9320802461997831))
# --> Test accuracy(confidence interval 0.95):(0.9105263157894739, (0.8668706512453495, 0.9541819803335982))
# --> Test f1(confidence interval 0.95):(0.885575861336731, (0.8329481653854373, 0.9382035572880248))
# --> Test recall(confidence interval 0.95):(0.9022741147741147, (0.8180723751977278, 0.9864758543505016))
# --> Test precision(confidence interval 0.95):(0.8241727716727716, (0.7024948764304061, 0.9458506669151371))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.8809090909090911
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9378205128205128, (0.8913647999417592, 0.9842762256992664))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8637488899988901, (0.7894162072638632, 0.938081572733917))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8198501882407023, 0.9275182328119291))
# --> Test f1(confidence interval 0.95):(0.80223604826546, (0.741695081629115, 0.862777014901805))
# --> Test recall(confidence interval 0.95):(0.9800000000000001, (0.9347568567451803, 1.02524314325482))
# --> Test precision(confidence interval 0.95):(0.5956746031746031, (0.4321243497710928, 0.7592248565781133))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 100, 'subsample': 0.8}
# Best CV auc_roc: 0.9272427572427573
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9075283050283052, (0.8514432897747528, 0.9636133202818575))
# --> Test balanced_accuracy(confidence interval 0.95):(0.852760434010434, (0.7892512149422786, 0.9162696530785894))
# --> Test accuracy(confidence interval 0.95):(0.8421052631578947, (0.7607711822053691, 0.9234393441104203))
# --> Test f1(confidence interval 0.95):(0.816004599265469, (0.7524727706461377, 0.8795364278848002))
# --> Test recall(confidence interval 0.95):(0.9069230769230769, (0.8254919468450488, 0.9883542070011051))
# --> Test precision(confidence interval 0.95):(0.7401515151515151, (0.62865590281479, 0.8516471274882402))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 1.0, 'gamma': 1.5, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9378646353646353
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.895792402042402, (0.843784897330791, 0.9477999067540129))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8943001443001443, (0.8517218907786535, 0.9368783978216351))
# --> Test accuracy(confidence interval 0.95):(0.8631578947368421, (0.8189643577760353, 0.907351431697649))
# --> Test f1(confidence interval 0.95):(0.841161109421979, (0.7649244597468762, 0.9173977590970818))
# --> Test recall(confidence interval 0.95):(0.8683658008658008, (0.7897651447426144, 0.9469664569889873))
# --> Test precision(confidence interval 0.95):(0.7873809523809524, (0.6915667781089905, 0.8831951266529143))
#
# ############################# GWAS datasets #############################
# ----------------Training dataset_19_----------------
# ---- No Feature Selection ----
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10883/697717569.py in <module>
#       1 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 2 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     499             self.perform_train_full()
#     500         if self.datasets_gwas:
# --> 501             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_gwas(self)
#     203
#     204             if "KNN" in self.train_models or "all" in self.train_models :
# --> 205                 self.train_KNN(dataset, metadata, dataset_name)
#     206             if "SGDClassifier" in self.train_models or "all" in self.train_models:
#     207                 self.train_SGDClassifier(dataset, metadata, dataset_name)
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in train_KNN(self, dataset, metadata, name)
#     318                             return_train_score=True,
#     319                             scoring='roc_auc')
# --> 320         grid.fit(x_train, y_train)
#     321
#     322         model_info = ["K-nearst neighbors", x_test, y_test, "KNN"]
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# ~/.local/lib/python3.9/site-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# ~/.local/lib/python3.9/site-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     398         if self._get_tags()["requires_y"]:
#     399             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 400                 X, y = self._validate_data(X, y, accept_sparse="csr", multi_output=True)
#     401
#     402             if is_classifier(self):
#
# ~/.local/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
#     577             out = X, y
#     578
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     954         raise ValueError("y cannot be None")
#     955
# --> 956     X = check_array(
#     957         X,
#     958         accept_sparse=accept_sparse,
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     736                     array = array.astype(dtype, casting="unsafe", copy=False)
#     737                 else:
# --> 738                     array = np.asarray(array, order=order, dtype=dtype)
#     739             except ComplexWarning as complex_warning:
#     740                 raise ValueError(
#
# ValueError: could not convert string to float: 'NR6097'

# %%
sys.path.append('../src/')
from TrainModels import *

datasets_full = []
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

feature_selection = {"method": None , "estimator": None }
train_models = ["all"]

TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# GWAS datasets #############################
# ----------------Training dataset_19_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.7983166833166833
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7420849983349982, (0.6679625670663274, 0.816207429603669))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6628241203241203, (0.5431419759117482, 0.7825062647364924))
# --> Test accuracy(confidence interval 0.95):(0.6263157894736843, (0.5565524665979796, 0.6960791123493889))
# --> Test f1(confidence interval 0.95):(0.6089997010363144, (0.5016408410806162, 0.7163585609920126))
# --> Test recall(confidence interval 0.95):(0.5473931623931624, (0.4206096294299168, 0.6741766953564079))
# --> Test precision(confidence interval 0.95):(0.7517676767676768, (0.6816184095030708, 0.8219169440322827))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.7219380619380621
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.4852777777777778, (0.46815714727168406, 0.5023984082838716))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6157894736842104, (0.5168900596331822, 0.7146888877352386))
# --> Test accuracy(confidence interval 0.95):(0.5736842105263158, (0.5016985709808223, 0.6456698500718093))
# --> Test f1(confidence interval 0.95):(0.0, (0.0, 0.0))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.0, (0.0, 0.0))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.888976023976024
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8681390831390832, (0.7994449004949359, 0.9368332657832305))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8166049228549228, (0.7578913615713507, 0.8753184841384949))
# --> Test accuracy(confidence interval 0.95):(0.7894736842105263, (0.7162945314692136, 0.862652836951839))
# --> Test f1(confidence interval 0.95):(0.7556531703590528, (0.6850706329067506, 0.8262357078113549))
# --> Test recall(confidence interval 0.95):(0.8490079365079366, (0.7489782018979806, 0.9490376711178926))
# --> Test precision(confidence interval 0.95):(0.6949098124098125, (0.5991968285730201, 0.7906227962466049))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.8542207792207792
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7557342657342658, (0.6973436820142781, 0.8141248494542536))
# --> Test balanced_accuracy(confidence interval 0.95):(0.729772866022866, (0.6331343895977288, 0.8264113424480031))
# --> Test accuracy(confidence interval 0.95):(0.6789473684210527, (0.5810081655941541, 0.7768865712479514))
# --> Test f1(confidence interval 0.95):(0.7012059662641839, (0.6268524352455443, 0.7755594972828234))
# --> Test recall(confidence interval 0.95):(0.6300000000000001, (0.5231334919529851, 0.7368665080470151))
# --> Test precision(confidence interval 0.95):(0.6250396825396826, (0.5168218021358431, 0.7332575629435221))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV auc_roc: 0.8600999000999001
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7907145632145631, (0.7056709238964488, 0.8757582025326774))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7050396825396826, (0.6482696309978269, 0.7618097340815384))
# --> Test accuracy(confidence interval 0.95):(0.7052631578947369, (0.6458651434525375, 0.7646611723369363))
# --> Test f1(confidence interval 0.95):(0.6443670821931692, (0.4592618886033945, 0.8294722757829438))
# --> Test recall(confidence interval 0.95):(0.7052869352869353, (0.5938494667157631, 0.8167244038581075))
# --> Test precision(confidence interval 0.95):(0.7013347763347764, (0.6216927118080661, 0.7809768408614867))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.001, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 500, 'subsample': 0.8}
# Best CV auc_roc: 0.8730094905094905
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8676323676323676, (0.8227509671565663, 0.912513768108169))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7542636530136531, (0.6676733477533999, 0.8408539582739062))
# --> Test accuracy(confidence interval 0.95):(0.7263157894736841, (0.6453699402411929, 0.8072616387061754))
# --> Test f1(confidence interval 0.95):(0.5043711843711844, (0.34483817391900184, 0.663904194823367))
# --> Test recall(confidence interval 0.95):(0.802063492063492, (0.6603280394903829, 0.9437989446366012))
# --> Test precision(confidence interval 0.95):(0.5713275613275612, (0.4060166488009778, 0.7366384738541447))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 1.5, 'learning_rate': 0.1, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.8865984015984015
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8669172494172492, (0.8093873037687996, 0.9244471950656988))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8267983405483406, (0.7496652618456678, 0.9039314192510133))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.7460426257283153, 0.875010005850632))
# --> Test f1(confidence interval 0.95):(0.702796876326288, (0.5475097419380309, 0.858084010714545))
# --> Test recall(confidence interval 0.95):(0.8533333333333333, (0.7491591167123504, 0.9575075499543162))
# --> Test precision(confidence interval 0.95):(0.7843181818181818, (0.6731407649987351, 0.8954955986376285))
# ----------------Training dataset_20_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 19, 'weights': 'distance'}
# Best CV auc_roc: 0.7701681286549709
# Best estimator metrics:
# error roc_auc
# --> Test roc_auc(confidence interval 0.95):(0.7382096171802054, (0.6136782465236438, 0.862740987836767))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8982456140350876, (0.8468602659046683, 0.9496309621655069))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.7436446488992305, 0.8774079826797168))
# --> Test f1(confidence interval 0.95):(0.09523809523809523, (-0.0620996198927144, 0.25257581036890486))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.14166666666666666, (-0.08323612083878162, 0.36656945417211495))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.7421491228070176
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7689097177332471, (0.6951549085753896, 0.8426645268911046))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6430250305250305, (0.5535533211589103, 0.7324967398911506))
# --> Test accuracy(confidence interval 0.95):(0.6, (0.5355163099388416, 0.6644836900611584))
# --> Test f1(confidence interval 0.95):(0.3355710955710956, (0.1804566294333099, 0.49068556170888133))
# --> Test recall(confidence interval 0.95):(0.22162698412698414, (0.12042296474026762, 0.32283100351370064))
# --> Test precision(confidence interval 0.95):(0.6833333333333333, (0.44191877737284724, 0.9247478892938195))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.8657456140350878
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8662044817927171, (0.7532080167399187, 0.9792009468455156))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8812317251461987, (0.8111068364772718, 0.9513566138151257))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684209, (0.7820099405144556, 0.8811479542223861))
# --> Test f1(confidence interval 0.95):(0.23238095238095235, (0.04272536310514355, 0.4220365416567612))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.12499999999999997, (0.00828415438036266, 0.24171584561963727))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.8846198830409356
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.898956043956044, (0.7821420477016091, 1.0157700402104788))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9337390658017594, (0.9085559667289075, 0.9589221648746112))
# --> Test accuracy(confidence interval 0.95):(0.905263157894737, (0.8663780297073858, 0.9441482860820882))
# --> Test f1(confidence interval 0.95):(0.6233333333333333, (0.48347744997258035, 0.7631892166940862))
# --> Test recall(confidence interval 0.95):(0.8666666666666666, (0.6362998570633971, 1.097033476269936))
# --> Test precision(confidence interval 0.95):(0.5666666666666667, (0.3548747215142303, 0.778458611819103))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# Best CV auc_roc: 0.8743713450292399
# Best estimator metrics:
# error roc_auc
# --> Test roc_auc(confidence interval 0.95):(0.8492929292929293, (0.7490736303330324, 0.9495122282528262))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8935672514619883, (0.8494656600173841, 0.9376688429065926))
# --> Test accuracy(confidence interval 0.95):(0.8052631578947368, (0.7489971701646282, 0.8615291456248454))
# --> Test f1(confidence interval 0.95):(0.08333333333333334, (-0.04544562817483219, 0.21211229484149888))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.13428571428571429, (0.024128243694160445, 0.24444318487726813))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 500, 'subsample': 0.6}
# Best CV auc_roc: 0.7944152046783625
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.69164592760181, (0.5777305994204178, 0.8055612557832021))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8882593739250085, (0.8341265197161428, 0.9423922281338742))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8198501882407023, 0.9275182328119291))
# --> Test f1(confidence interval 0.95):(0.2633333333333333, (0.04903558931103527, 0.4776310773556314))
# --> Test recall(confidence interval 0.95):(0.95, (0.8368921418629504, 1.0631078581370494))
# --> Test precision(confidence interval 0.95):(0.13333333333333336, (-0.09007214072183278, 0.3567388073884995))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9259795321637428
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9046988795518207, (0.8281714565447356, 0.9812263025589059))
# --> Test balanced_accuracy(confidence interval 0.95):(0.982906776745786, (0.9661965895297812, 0.9996169639617908))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842106, (0.8715959367234037, 0.9599830106450175))
# --> Test f1(confidence interval 0.95):(0.7599567099567099, (0.615956978299198, 0.9039564416142218))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.78, (0.5935254888523294, 0.9664745111476707))
# ----------------Training dataset_21_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8188400057603686
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8376920116920117, (0.7939781965565504, 0.8814058268274729))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7389808324888969, (0.6943220614604589, 0.7836396035173349))
# --> Test accuracy(confidence interval 0.95):(0.7710526315789473, (0.742919637713893, 0.7991856254440016))
# --> Test f1(confidence interval 0.95):(0.6632178246649263, (0.6018093492121022, 0.7246263001177504))
# --> Test recall(confidence interval 0.95):(0.7380619380619381, (0.6366976721071075, 0.8394262040167687))
# --> Test precision(confidence interval 0.95):(0.6975351935646052, (0.6026383168748018, 0.7924320702544086))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8142367511520737
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7306260212714017, (0.6708299912780437, 0.7904220512647598))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6954714353843612, (0.6608636153178429, 0.7300792554508795))
# --> Test accuracy(confidence interval 0.95):(0.6921052631578948, (0.6442746455175984, 0.7399358807981912))
# --> Test f1(confidence interval 0.95):(0.5905161200517237, (0.5441884516058556, 0.6368437884975918))
# --> Test recall(confidence interval 0.95):(0.4786378446115288, (0.3633456799533266, 0.5939300092697309))
# --> Test precision(confidence interval 0.95):(0.7568903318903318, (0.7017564819275254, 0.8120241818531383))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.8919138824884794
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8953076892005714, (0.8539068006277643, 0.9367085777733785))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8241594618320962, (0.7728304066634597, 0.8754885170007327))
# --> Test accuracy(confidence interval 0.95):(0.8394736842105261, (0.806927950794178, 0.8720194176268743))
# --> Test f1(confidence interval 0.95):(0.7532976011599859, (0.6931908787985763, 0.8134043235213955))
# --> Test recall(confidence interval 0.95):(0.6925108225108225, (0.6194906211898799, 0.7655310238317652))
# --> Test precision(confidence interval 0.95):(0.7811754911754911, (0.6885803299841693, 0.873770652366813))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# Best CV auc_roc: 0.8098521505376344
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7527380952380953, (0.678271945971935, 0.8272042445042557))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7263157894736842, (0.6729224350826102, 0.7797091438647583))
# --> Test accuracy(confidence interval 0.95):(0.7131578947368421, (0.652675945437504, 0.7736398440361802))
# --> Test f1(confidence interval 0.95):(0.0, (0.0, 0.0))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.0, (0.0, 0.0))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.9000199212749616
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9078611365486365, (0.8781631649131858, 0.9375591081840873))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7613549738482999, (0.6807065210159046, 0.8420034266806952))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894737, (0.7710382814440694, 0.8500143501348779))
# --> Test f1(confidence interval 0.95):(0.7283896015694895, (0.6762278427368993, 0.7805513604020797))
# --> Test recall(confidence interval 0.95):(0.6632721445221446, (0.5678702419632295, 0.7586740470810596))
# --> Test precision(confidence interval 0.95):(0.6161546786546788, (0.5068628196960332, 0.7254465376133243))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 200, 'subsample': 1.0}
# Best CV auc_roc: 0.9248300691244241
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9109494354346304, (0.8742331829723259, 0.9476656878969348))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8167643107006288, (0.7695215522562271, 0.8640070691450306))
# --> Test accuracy(confidence interval 0.95):(0.85, (0.8013531012871251, 0.8986468987128748))
# --> Test f1(confidence interval 0.95):(0.7294651611866303, (0.6317386354016172, 0.8271916869716434))
# --> Test recall(confidence interval 0.95):(0.6838865301365301, (0.6051065038931827, 0.7626665563798776))
# --> Test precision(confidence interval 0.95):(0.6611455537926126, (0.5691924534816559, 0.7530986541035694))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 1.5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9300873655913978
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8833587110526764, (0.8355060863872021, 0.9312113357181506))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7560736977788195, (0.7011156147649615, 0.8110317807926775))
# --> Test accuracy(confidence interval 0.95):(0.8263157894736842, (0.7751827083857485, 0.8774488705616199))
# --> Test f1(confidence interval 0.95):(0.6911651273550585, (0.6319362585123383, 0.7503939961977788))
# --> Test recall(confidence interval 0.95):(0.7284217171717171, (0.6027136031052388, 0.8541298312381954))
# --> Test precision(confidence interval 0.95):(0.6597835497835499, (0.5333433945603001, 0.7862237050067997))
