# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
sys.path.append('../src/')
from TrainModels import *

# %%
datasets_full = ['dataset_1_', 'dataset_2_', 'dataset_3_', 'dataset_7_']
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

# %%
feature_selection = {"method": None , "estimator": None }
# train_models = ["KNN","SGDClassifier","LogisticRegression","SVC","RandomForestClassifier","GBTC","XGB","MLPClassifier"]

# %%
train_models = ["KNN"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- No Feature Selection ----
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.8088836163836165
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8344355644355644, (0.7617548138122164, 0.9071163150589124))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7355291195732372, (0.6618425808475793, 0.8092156582988951))
# --> Test accuracy(confidence interval 0.95):(0.7157894736842106, (0.6421811140206565, 0.7893978333477648))
# --> Test f1(confidence interval 0.95):(0.7244971645291339, (0.6604913565915232, 0.7885029724667446))
# --> Test recall(confidence interval 0.95):(0.685952380952381, (0.5439972984783488, 0.8279074634264132))
# --> Test precision(confidence interval 0.95):(0.6974603174603174, (0.5746193443143733, 0.8203012906062616))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9471/1073640720.py in <module>
#       1 train_models = ["KNN"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_KNN.pkl'

# %%
train_models = ["SGDClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- No Feature Selection ----
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8704145854145855
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8947907647907648, (0.8407533529331388, 0.9488281766483908))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9137277999777998, (0.8692876040403343, 0.9581679959152654))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421052, (0.7867896887236476, 0.9289997849605627))
# --> Test f1(confidence interval 0.95):(0.8577215023725321, (0.8069923714358895, 0.9084506333091746))
# --> Test recall(confidence interval 0.95):(0.8852272727272726, (0.8187510112124948, 0.9517035342420505))
# --> Test precision(confidence interval 0.95):(0.8801576201576202, (0.8171865493863795, 0.943128690928861))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9471/1726060269.py in <module>
#       1 train_models = ["SGDClassifier"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_SGDC.pkl'

# %%
train_models = ["LogisticRegression"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()

# %%
train_models = ["SVC"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()

# %%
train_models = ["RandomForestClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()

# %%
train_models = ["GBTC"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()

# %%
train_models = ["XGB"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()

# %%
train_models = ["MLPClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
