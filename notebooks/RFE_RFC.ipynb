# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
sys.path.append('../src/')
from TrainModels import *

# %%
datasets_full = ['dataset_1_', 'dataset_2_', 'dataset_3_', 'dataset_7_']
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

# %%
feature_selection = {"method" : "RFE" , "estimator" : "RFC" }
# train_models = ["KNN","SGDClassifier","LogisticRegression","SVC","RandomForestClassifier","GBTC","XGB","MLPClassifier"]
train_models = ["all"]

# %%
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 238
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8244805194805196
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8444223831723832, (0.7946694481093035, 0.8941753182354628))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7337240537240537, (0.6494723783079555, 0.8179757291401519))
# --> Test accuracy(confidence interval 0.95):(0.6684210526315789, (0.5995667369657163, 0.7372753682974416))
# --> Test f1(confidence interval 0.95):(0.7099891774891776, (0.644212046951285, 0.7757663080270701))
# --> Test recall(confidence interval 0.95):(0.5958333333333333, (0.4206242944425689, 0.7710423722240978))
# --> Test precision(confidence interval 0.95):(0.6768290043290043, (0.569626076334892, 0.7840319323231165))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.8952547452547452
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8931240981240982, (0.8481025568735129, 0.9381456393746835))
# --> Test balanced_accuracy(confidence interval 0.95):(0.878896103896104, (0.8345609350332157, 0.9232312727589922))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210527, (0.8285902516348731, 0.9293044852072323))
# --> Test f1(confidence interval 0.95):(0.8596650717703348, (0.7664342284598691, 0.9528959150808005))
# --> Test recall(confidence interval 0.95):(0.8852344877344878, (0.8009101426995752, 0.9695588327694004))
# --> Test precision(confidence interval 0.95):(0.8389285714285715, (0.7662817375465213, 0.9115754053106216))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9093906093906095
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.921254578754579, (0.8740757923138378, 0.9684333651953201))
# --> Test balanced_accuracy(confidence interval 0.95):(0.913211371961372, (0.8745950096717826, 0.9518277342509615))
# --> Test accuracy(confidence interval 0.95):(0.8842105263157893, (0.8286487714414492, 0.9397722811901295))
# --> Test f1(confidence interval 0.95):(0.8797849696705532, (0.8172674073640076, 0.9423025319770988))
# --> Test recall(confidence interval 0.95):(0.9409920634920634, (0.8822937885188239, 0.999690338465303))
# --> Test precision(confidence interval 0.95):(0.7927777777777778, (0.6960077213716354, 0.8895478341839202))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best CV auc_roc: 0.9230919080919081
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9803088578088579, (0.9578917620843145, 1.0027259535334014))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9013300588300588, (0.8661765059089802, 0.9364836117511374))
# --> Test accuracy(confidence interval 0.95):(0.8842105263157893, (0.8496122299410712, 0.9188088226905075))
# --> Test f1(confidence interval 0.95):(0.8716348563716985, (0.790710255676345, 0.9525594570670519))
# --> Test recall(confidence interval 0.95):(0.9208333333333334, (0.823030335648298, 1.0186363310183688))
# --> Test precision(confidence interval 0.95):(0.7927597402597403, (0.6957619339128468, 0.8897575466066338))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV auc_roc: 0.9136663336663338
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8883398545898545, (0.8295968638911188, 0.9470828452885903))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8942696274313923, (0.8596081720654778, 0.9289310827973067))
# --> Test accuracy(confidence interval 0.95):(0.7842105263157895, (0.732617468218188, 0.835803584413391))
# --> Test f1(confidence interval 0.95):(0.7980614999036051, (0.7311105783856302, 0.86501242142158))
# --> Test recall(confidence interval 0.95):(0.9409920634920634, (0.8822937885188239, 0.999690338465303))
# --> Test precision(confidence interval 0.95):(0.7277597402597402, (0.6384161358933327, 0.8171033446261478))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 200, 'subsample': 1.0}
# Best CV auc_roc: 0.8736613386613387
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8731041181041181, (0.79160824139249, 0.9545999948157463))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9075717338217337, (0.8731642696028378, 0.9419791980406297))
# --> Test accuracy(confidence interval 0.95):(0.9, (0.8585655892099239, 0.9414344107900762))
# --> Test f1(confidence interval 0.95):(0.8102171329664936, (0.7435271348530167, 0.8769071310799704))
# --> Test recall(confidence interval 0.95):(0.9166666666666666, (0.7878877051585012, 1.045445628174832))
# --> Test precision(confidence interval 0.95):(0.7274025974025974, (0.6112917663629415, 0.8435134284422533))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.8}
# Best CV auc_roc: 0.9076323676323677
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.868167388167388, (0.7919303533709967, 0.9444044229637794))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9513535076035076, (0.9123806686413649, 0.9903263465656502))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842106, (0.879415766904747, 0.9521631804636742))
# --> Test f1(confidence interval 0.95):(0.8515212857318121, (0.7674539533154835, 0.9355886181481406))
# --> Test recall(confidence interval 0.95):(0.8646031746031747, (0.786123842273838, 0.9430825069325114))
# --> Test precision(confidence interval 0.95):(0.8317748917748917, (0.7616143333894464, 0.901935450160337))
# Perform Multi-layer Perceptron training.
#
# *********Multi-layer Perceptron*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 'constant', 'solver': 'lbfgs', 'warm_start': True}
# Best CV auc_roc: nan
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.5274819624819624, (0.4718869144052676, 0.5830770105586572))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_375160/986404798.py in <module>
#       1 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 2 TM.main()
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     178                 self.perform_XGB(dataset, metadata, dataset_name)
#     179             if "MLPClassifier" in self.train_models or "all" in self.train_models:
# --> 180                 self.train_MLPC(dataset,metadata,dataset_name)
#     181
#     182             for model in self.models:
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in train_MLPC(self, dataset, metadata, name)
#     340         model_info = ["Multi-layer Perceptron", x_test, y_test, "MLP"]
#     341
# --> 342         self.print_performance_metrics(grid, model_info[0], model_info[1],
#     343                                        model_info[2], name, model_info[3])
#     344
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in print_performance_metrics(self, grid, name, x_test, y_test, dataset, short_name, xgboost)
#     141             print("--> Test {}(confidence interval 0.95):{}"
#     142                   .format(metric,
# --> 143                           self.mean_confidence_interval(grid.best_estimator_,
#     144                                                         x_test, y_test,
#     145                                                         scoring=metric,
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in mean_confidence_interval(self, grid, x_test, y_test, xgboost, confidence, scoring)
#      97                 y_pred = grid.predict(x_sample_array)
#      98
# ---> 99             score = self.calculate_metrics(y_pred, y_sample_array, scoring)
#     100             score_array.append(score)
#     101
#
# ~/Insync/arthcrs@gmail.com/Google Drive/College/TCC/Repositories/tcc_acrs/notebooks/../src/TrainModels.py in calculate_metrics(x, y, scoring)
#     119                 return 1
#     120         elif scoring == 'balanced_accuracy':
# --> 121             return balanced_accuracy_score(x, y)
#     122         elif scoring == 'f1':
#     123             return f1_score(x, y)
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in balanced_accuracy_score(y_true, y_pred, sample_weight, adjusted)
#    1947
#    1948     """
# -> 1949     C = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
#    1950     with np.errstate(divide="ignore", invalid="ignore"):
#    1951         per_class = np.diag(C) / C.sum(axis=1)
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     300
#     301     """
# --> 302     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     303     if y_type not in ("binary", "multiclass"):
#     304         raise ValueError("%s is not supported" % y_type)
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets

# %%
train_models = ["KNN","SGDClassifier","LogisticRegression","SVC","RandomForestClassifier","GBTC","XGB","MLPClassifier"]
