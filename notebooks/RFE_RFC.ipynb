# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

sys.path.append('../src/')
from TrainModels import *

# %%
datasets_full = ['dataset_1_', 'dataset_2_', 'dataset_3_', 'dataset_7_']
datasets_gwas = []

feature_selection = {"method": "RFE" , "estimator": "RFC" }
train_models = ["all"]

TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 238
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8244805194805196
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8489448051948052, (0.7757133191463883, 0.9221762912432221))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7365274309024309, (0.6598772756143136, 0.8131775861905481))
# --> Test accuracy(confidence interval 0.95):(0.7421052631578947, (0.6525673826837688, 0.8316431436320206))
# --> Test f1(confidence interval 0.95):(0.6116814094058676, (0.492314661463178, 0.7310481573485571))
# --> Test recall(confidence interval 0.95):(0.7213095238095238, (0.5904372712145389, 0.8521817764045088))
# --> Test precision(confidence interval 0.95):(0.5222835497835498, (0.3655423216334053, 0.6790247779336944))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.8952547452547452
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9500471750471752, (0.895455037997931, 1.0046393120964194))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8730898268398267, (0.8196451589179162, 0.9265344947617372))
# --> Test accuracy(confidence interval 0.95):(0.8894736842105264, (0.8480392734204503, 0.9309080950006026))
# --> Test f1(confidence interval 0.95):(0.8341275700563626, (0.7783629017906114, 0.8898922383221138))
# --> Test recall(confidence interval 0.95):(0.8533730158730158, (0.768700591522313, 0.9380454402237187))
# --> Test precision(confidence interval 0.95):(0.7943650793650793, (0.6511530330039469, 0.9375771257262117))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9093906093906095
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9327713952713953, (0.8801007491814691, 0.9854420413613215))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8786380286380286, (0.8310080277908131, 0.9262680294852442))
# --> Test accuracy(confidence interval 0.95):(0.8736842105263157, (0.8198501882407023, 0.9275182328119291))
# --> Test f1(confidence interval 0.95):(0.8209963411201802, (0.7581819207599714, 0.883810761480389))
# --> Test recall(confidence interval 0.95):(0.9800000000000001, (0.9347568567451803, 1.02524314325482))
# --> Test precision(confidence interval 0.95):(0.8169841269841271, (0.7497144588952301, 0.8842537950730242))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best CV auc_roc: 0.9230919080919081
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9229112554112554, (0.8745965930890268, 0.971225917733484))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8820815295815297, (0.7660431350714423, 0.9981199240916172))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842105, (0.8753165490679649, 0.9562623983004561))
# --> Test f1(confidence interval 0.95):(0.8164912375206492, (0.7508522963649903, 0.8821301786763082))
# --> Test recall(confidence interval 0.95):(0.9523809523809523, (0.8737120948155475, 1.0310498099463572))
# --> Test precision(confidence interval 0.95):(0.7679509379509379, (0.6848322703341696, 0.8510696055677063))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV auc_roc: 0.9136663336663338
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9365370740370741, (0.8981235397688867, 0.9749506083052615))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8733474858474859, (0.8150199452788781, 0.9316750264160937))
# --> Test accuracy(confidence interval 0.95):(0.8947368421052632, (0.8477785885730317, 0.9416950956374947))
# --> Test f1(confidence interval 0.95):(0.7607669552669553, (0.673315753375411, 0.8482181571584995))
# --> Test recall(confidence interval 0.95):(0.9497222222222224, (0.9017524534793466, 0.9976919909650981))
# --> Test precision(confidence interval 0.95):(0.8015800865800866, (0.7202739139502441, 0.8828862592099291))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 200, 'subsample': 1.0}
# Best CV auc_roc: 0.8736613386613387
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9352156177156179, (0.8817895922513842, 0.9886416431798516))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9002772227772228, (0.8565767615996587, 0.9439776839547869))
# --> Test accuracy(confidence interval 0.95):(0.868421052631579, (0.8206316150399332, 0.9162104902232248))
# --> Test f1(confidence interval 0.95):(0.8213648872627202, (0.7557767115822005, 0.8869530629432398))
# --> Test recall(confidence interval 0.95):(0.9875, (0.9592230354657376, 1.0157769645342625))
# --> Test precision(confidence interval 0.95):(0.7839543789543789, (0.652338193253895, 0.9155705646548629))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 0.8}
# Best CV auc_roc: 0.9076323676323677
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8944347319347319, (0.825557100157037, 0.9633123637124268))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8510456210456212, (0.7970296369974257, 0.9050616050938167))
# --> Test accuracy(confidence interval 0.95):(0.894736842105263, (0.8477785885730316, 0.9416950956374945))
# --> Test f1(confidence interval 0.95):(0.859697247197247, (0.7901935960418424, 0.9292008983526517))
# --> Test recall(confidence interval 0.95):(0.9268772893772894, (0.8532905992123854, 1.0004639795421935))
# --> Test precision(confidence interval 0.95):(0.8427777777777777, (0.738922439326223, 0.9466331162293324))
# ----------------Training dataset_2_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 363
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 13, 'weights': 'distance'}
# Best CV auc_roc: 0.7680116959064327
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7405263772175538, (0.5374425471615927, 0.9436102072735149))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9266855865153077, (0.8815329691244349, 0.9718382039061806))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210527, (0.8124198876052248, 0.9454748492368806))
# --> Test f1(confidence interval 0.95):(0.4276190476190476, (0.16871901267629474, 0.6865190825618005))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.41, (0.15882521132108124, 0.6611747886789188))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.8610964912280702
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8663432645785587, (0.7986929864370806, 0.9339935427200368))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9367127991547495, (0.8999227233472374, 0.9735028749622615))
# --> Test accuracy(confidence interval 0.95):(0.9105263157894736, (0.8330604451478171, 0.9879921864311302))
# --> Test f1(confidence interval 0.95):(0.43666666666666665, (0.15175191925542192, 0.7215814140779113))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.4999999999999999, (0.21898126712906035, 0.7810187328709395))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.8893859649122808
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9122462831286361, (0.8489529645909618, 0.9755396016663104))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8425917121234459, (0.7223722684341154, 0.9628111558127763))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.831821705254334, 0.9260730315877712))
# --> Test f1(confidence interval 0.95):(0.6279365079365079, (0.37663632930611135, 0.8792366865669045))
# --> Test recall(confidence interval 0.95):(0.7683333333333333, (0.5411109626861176, 0.995555703980549))
# --> Test precision(confidence interval 0.95):(0.4588095238095238, (0.18294450339364499, 0.7346745442254026))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# Best CV auc_roc: 0.9447807017543859
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9415873015873016, (0.8898895803480834, 0.9932850228265199))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9346033281733745, (0.9025043956932468, 0.9667022606535023))
# --> Test accuracy(confidence interval 0.95):(0.9, (0.8549242695052572, 0.9450757304947428))
# --> Test f1(confidence interval 0.95):(0.7259090909090908, (0.5143357368151533, 0.9374824450030284))
# --> Test recall(confidence interval 0.95):(0.9666666666666666, (0.8912614279086335, 1.0420719054246996))
# --> Test precision(confidence interval 0.95):(0.68, (0.5406419065108108, 0.8193580934891893))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.9205409356725147
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9525195719313366, (0.920925323881481, 0.9841138199811923))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8296476485330974, (0.6837978104690948, 0.9754974865970999))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.8078423203025951, 0.9500524165395101))
# --> Test f1(confidence interval 0.95):(0.6333333333333334, (0.43225269664524535, 0.8344139700214215))
# --> Test recall(confidence interval 0.95):(0.875, (0.7230158823901864, 1.0269841176098136))
# --> Test precision(confidence interval 0.95):(0.4116666666666666, (0.17440629334463761, 0.6489270399886956))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 50, 'n_estimators': 500, 'subsample': 0.6}
# Best CV auc_roc: 0.7990497076023392
# Best estimator metrics:
# error roc_auc
# --> Test roc_auc(confidence interval 0.95):(0.5486029411764706, (0.39524046446724703, 0.7019654178856941))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6953379772961816, (0.5450537408597151, 0.8456222137326481))
# --> Test accuracy(confidence interval 0.95):(0.8105263157894738, (0.7629019544686108, 0.8581506771103368))
# --> Test f1(confidence interval 0.95):(0.27874458874458874, (0.09131233373422559, 0.4661768437549519))
# --> Test recall(confidence interval 0.95):(0.5366666666666667, (0.25353140264760954, 0.8198019306857239))
# --> Test precision(confidence interval 0.95):(0.15833333333333333, (0.0032629288574105575, 0.3134037378092561))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.8956140350877193
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9096218487394957, (0.8231329423078693, 0.9961107551711221))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8327205882352942, (0.7498343399952224, 0.9156068364753659))
# --> Test accuracy(confidence interval 0.95):(0.8368421052631578, (0.791766374768415, 0.8819178357579006))
# --> Test f1(confidence interval 0.95):(0.41309523809523807, (0.26868008674841964, 0.5575103894420566))
# --> Test recall(confidence interval 0.95):(0.8400000000000001, (0.5894548177373952, 1.090545182262605))
# --> Test precision(confidence interval 0.95):(0.47333333333333333, (0.26950658933665783, 0.6771600773300088))
# ----------------Training dataset_3_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 219
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8532927707373272
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7981704524567428, (0.7335530662211969, 0.8627878386922887))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7566743599932642, (0.6532548503494907, 0.8600938696370376))
# --> Test accuracy(confidence interval 0.95):(0.7605263157894737, (0.7115567143760244, 0.809495917202923))
# --> Test f1(confidence interval 0.95):(0.5614787786459614, (0.4727416413459336, 0.6502159159459893))
# --> Test recall(confidence interval 0.95):(0.8058108558108558, (0.7009509484958828, 0.9106707631258287))
# --> Test precision(confidence interval 0.95):(0.5050124875124875, (0.370276622003754, 0.639748353021221))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9137711213517665
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8607263954867911, (0.7988029133733401, 0.9226498776002421))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8442498844546258, (0.792172417014495, 0.8963273518947565))
# --> Test accuracy(confidence interval 0.95):(0.8157894736842106, (0.7714180948098518, 0.8601608525585694))
# --> Test f1(confidence interval 0.95):(0.6438558468273773, (0.5684135684507954, 0.7192981252039592))
# --> Test recall(confidence interval 0.95):(0.8634054834054833, (0.7961435748065957, 0.9306673920043709))
# --> Test precision(confidence interval 0.95):(0.6097181086886969, (0.5109360766643964, 0.7085001407129974))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'penalty': 'l2'}
# Best CV auc_roc: 0.9166388248847926
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8464317978993041, (0.7924067182717812, 0.900456877526827))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8267842996722307, (0.7845155895860205, 0.8690530097584408))
# --> Test accuracy(confidence interval 0.95):(0.8552631578947368, (0.810670474012243, 0.8998558417772307))
# --> Test f1(confidence interval 0.95):(0.6987424957945889, (0.643636378076582, 0.7538486135125958))
# --> Test recall(confidence interval 0.95):(0.6997222222222221, (0.6114186714574742, 0.7880257729869701))
# --> Test precision(confidence interval 0.95):(0.7344488844488845, (0.6487583577029923, 0.8201394111947766))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best CV auc_roc: 0.9352520161290323
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9155709025865674, (0.8958363652915609, 0.9353054398815739))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8604630160106052, (0.8060840965650903, 0.91484193545612))
# --> Test accuracy(confidence interval 0.95):(0.8342105263157894, (0.8075138491202524, 0.8609072035113264))
# --> Test f1(confidence interval 0.95):(0.794937395354679, (0.7436812683955589, 0.8461935223137991))
# --> Test recall(confidence interval 0.95):(0.8070851370851371, (0.7358954635124708, 0.8782748106578033))
# --> Test precision(confidence interval 0.95):(0.7023953823953824, (0.6033842858878967, 0.801406478902868))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 400}
# Best CV auc_roc: 0.9375518433179723
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9374683002183002, (0.9049859721069159, 0.9699506283296845))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8370423255723098, (0.7872404275695835, 0.8868442235750362))
# --> Test accuracy(confidence interval 0.95):(0.8342105263157894, (0.8123826940437272, 0.8560383585878516))
# --> Test f1(confidence interval 0.95):(0.6557876729005763, (0.5654915676054294, 0.7460837781957231))
# --> Test recall(confidence interval 0.95):(0.8051118326118326, (0.6993296900788475, 0.9108939751448177))
# --> Test precision(confidence interval 0.95):(0.6312678987678988, (0.5311197038503814, 0.7314160936854162))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 500, 'subsample': 1.0}
# Best CV auc_roc: 0.9223648713517665
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8800537218417652, (0.8374039741465539, 0.9227034695369766))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8397769048620976, (0.7900438515388436, 0.8895099581853515))
# --> Test accuracy(confidence interval 0.95):(0.8631578947368421, (0.8147137768095996, 0.9116020126640847))
# --> Test f1(confidence interval 0.95):(0.673542167326997, (0.6297825227524068, 0.7173018119015873))
# --> Test recall(confidence interval 0.95):(0.7645995670995671, (0.6332323310616679, 0.8959668031374663))
# --> Test precision(confidence interval 0.95):(0.7237196137196137, (0.651103457274557, 0.7963357701646704))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 2, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.922898665514593
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8383538935974233, (0.7841887815369315, 0.8925190056579151))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8963632970567676, (0.8477712537908735, 0.9449553403226618))
# --> Test accuracy(confidence interval 0.95):(0.8552631578947368, (0.8025750647319664, 0.9079512510575073))
# --> Test f1(confidence interval 0.95):(0.780111783183312, (0.7183805651362023, 0.8418430012304217))
# --> Test recall(confidence interval 0.95):(0.8545238095238096, (0.7436859253707654, 0.9653616936768538))
# --> Test precision(confidence interval 0.95):(0.642967587967588, (0.5242690910277191, 0.7616660849074569))
# ----------------Training dataset_7_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 209
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8523626373626373
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9053084415584415, (0.870797075603653, 0.9398198075132299))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8214817208934855, (0.7594743684271795, 0.8834890733597914))
# --> Test accuracy(confidence interval 0.95):(0.8157894736842106, (0.7464791641896121, 0.8850997831788091))
# --> Test f1(confidence interval 0.95):(0.6853376087277016, (0.6036086801567702, 0.7670665372986329))
# --> Test recall(confidence interval 0.95):(0.9187362637362637, (0.8499579479787436, 0.9875145794937839))
# --> Test precision(confidence interval 0.95):(0.6011544011544011, (0.48978702583204264, 0.7125217764767595))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9391758241758241
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9541125541125541, (0.9158729594613945, 0.9923521487637138))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9039954489954491, (0.8550131116866915, 0.9529777863042068))
# --> Test accuracy(confidence interval 0.95):(0.9263157894736842, (0.8899420826942206, 0.9626894962531478))
# --> Test f1(confidence interval 0.95):(0.8921507733528194, (0.8377318714580413, 0.9465696752475976))
# --> Test recall(confidence interval 0.95):(0.8411197136197137, (0.7543817729973462, 0.9278576542420812))
# --> Test precision(confidence interval 0.95):(0.8807900432900434, (0.810157008316322, 0.9514230782637648))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'penalty': 'l2'}
# Best CV auc_roc: 0.9332717282717283
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9385001110001111, (0.9036829994075952, 0.973317222592627))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8884158896658896, (0.8500042272975495, 0.9268275520342296))
# --> Test accuracy(confidence interval 0.95):(0.9052631578947367, (0.8442948811522859, 0.9662314346371874))
# --> Test f1(confidence interval 0.95):(0.8397972761672452, (0.7766031236444736, 0.9029914286900168))
# --> Test recall(confidence interval 0.95):(0.7789285714285714, (0.6483632896614091, 0.9094938531957337))
# --> Test precision(confidence interval 0.95):(0.8431410256410257, (0.7304681977275801, 0.9558138535544712))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.001, 'gamma': 1, 'kernel': 'poly'}
# Best CV auc_roc: 0.9472927072927073
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9709945609945609, (0.9464637609066539, 0.995525361082468))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9423399517149516, (0.9072019229534337, 0.9774779804764694))
# --> Test accuracy(confidence interval 0.95):(0.9052631578947368, (0.8417640094669194, 0.9687623063225541))
# --> Test f1(confidence interval 0.95):(0.913494936436113, (0.8684255350198522, 0.9585643378523738))
# --> Test recall(confidence interval 0.95):(0.9428571428571428, (0.8714026045178399, 1.0143116811964457))
# --> Test precision(confidence interval 0.95):(0.8345165945165945, (0.7635964209782848, 0.9054367680549043))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# Best CV auc_roc: 0.9317782217782217
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9516724941724941, (0.8981108798991017, 1.0052341084458865))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9249213286713287, (0.8910515464054753, 0.9587911109371821))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842105, (0.8681651123633475, 0.9634138350050735))
# --> Test f1(confidence interval 0.95):(0.8310299809596484, (0.7502726402416328, 0.9117873216776641))
# --> Test recall(confidence interval 0.95):(0.8748376623376624, (0.7959540617814019, 0.9537212628939228))
# --> Test precision(confidence interval 0.95):(0.8484274059274058, (0.7835389972825256, 0.913315814572286))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 100, 'subsample': 0.8}
# Best CV auc_roc: 0.9308391608391607
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8704840992340992, (0.801354664492899, 0.9396135339752993))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8371940559440558, (0.7344723966078013, 0.9399157152803104))
# --> Test accuracy(confidence interval 0.95):(0.9, (0.8625593894893944, 0.9374406105106057))
# --> Test f1(confidence interval 0.95):(0.8204487179487179, (0.7214195304430098, 0.919477905454426))
# --> Test recall(confidence interval 0.95):(0.8210245310245309, (0.7392868398402808, 0.902762222208781))
# --> Test precision(confidence interval 0.95):(0.879318181818182, (0.7860343006547986, 0.9726020629815654))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9398126873126873
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9356604506604507, (0.8808712814083001, 0.9904496199126013))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8585281385281386, (0.8036634473963671, 0.9133928296599101))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684211, (0.7632989062488833, 0.8998589884879589))
# --> Test f1(confidence interval 0.95):(0.8552738541128635, (0.805379555449306, 0.905168152776421))
# --> Test recall(confidence interval 0.95):(0.8756313131313131, (0.7804481500529227, 0.9708144762097036))
# --> Test precision(confidence interval 0.95):(0.9001984126984126, (0.842260859952746, 0.9581359654440792))

# %%
datasets_full = []
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

feature_selection = {"method": "RFE" , "estimator": "RFC" }
train_models = ["all"]

TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# GWAS datasets #############################
# ----------------Training dataset_19_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 263
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 3, 'weights': 'distance'}
# Best CV auc_roc: 0.8463836163836163
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7917155067155066, (0.7118684849071306, 0.8715625285238826))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7083993783993783, (0.626443542052839, 0.7903552147459175))
# --> Test accuracy(confidence interval 0.95):(0.6473684210526315, (0.5883695019323744, 0.7063673401728886))
# --> Test f1(confidence interval 0.95):(0.6374864746536573, (0.5584526825169916, 0.7165202667903229))
# --> Test recall(confidence interval 0.95):(0.6285839160839161, (0.5061517957044384, 0.7510160364633938))
# --> Test precision(confidence interval 0.95):(0.6432264957264957, (0.5543307759022672, 0.7321222155507242))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.7383066933066933
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.6562103174603174, (0.594568570271275, 0.7178520646493599))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7223523576097105, (0.6568925001780059, 0.7878122150414151))
# --> Test accuracy(confidence interval 0.95):(0.6368421052631578, (0.5490809466695923, 0.7246032638567232))
# --> Test f1(confidence interval 0.95):(0.7142828084704516, (0.6373387712171116, 0.7912268457237915))
# --> Test recall(confidence interval 0.95):(0.6715164002664002, (0.5532776944869389, 0.7897551060458616))
# --> Test precision(confidence interval 0.95):(0.8989926739926741, (0.8264726440364393, 0.971512703948909))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9017082917082918
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8875921300921302, (0.8300798757591372, 0.9451043844251232))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8126311188811188, (0.7567839971764524, 0.8684782405857853))
# --> Test accuracy(confidence interval 0.95):(0.8, (0.7171311784198477, 0.8828688215801523))
# --> Test f1(confidence interval 0.95):(0.7349689062227762, (0.6688023275764532, 0.8011354848690992))
# --> Test recall(confidence interval 0.95):(0.7330050505050505, (0.6638847855317831, 0.8021253154783179))
# --> Test precision(confidence interval 0.95):(0.7606929181929182, (0.6263506442674119, 0.8950351921184244))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.8605244755244754
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7857908757908758, (0.6739408582805368, 0.8976408933012148))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7238280469530469, (0.6409309039022786, 0.8067251900038153))
# --> Test accuracy(confidence interval 0.95):(0.7578947368421052, (0.7012104088707706, 0.8145790648134398))
# --> Test f1(confidence interval 0.95):(0.6585900812294001, (0.5419541515704633, 0.7752260108883369))
# --> Test recall(confidence interval 0.95):(0.8415476190476191, (0.6843849319234683, 0.9987103061717699))
# --> Test precision(confidence interval 0.95):(0.5736111111111112, (0.4491098041583157, 0.6981124180639067))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# Best CV auc_roc: 0.9209565434565434
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8957514707514708, (0.8318295423678477, 0.9596733991350939))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8061365023865024, (0.7432243074930724, 0.8690486972799323))
# --> Test accuracy(confidence interval 0.95):(0.8526315789473683, (0.7891324305195511, 0.9161307273751855))
# --> Test f1(confidence interval 0.95):(0.8321398214115941, (0.7786809881393348, 0.8855986546838535))
# --> Test recall(confidence interval 0.95):(0.8348376623376623, (0.7654229272068095, 0.9042523974685152))
# --> Test precision(confidence interval 0.95):(0.7846103896103895, (0.6658770232636421, 0.903343755957137))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.001, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 500, 'subsample': 0.8}
# Best CV auc_roc: 0.8729395604395604
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8511219336219336, (0.7981852974193688, 0.9040585698244983))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7144679503503033, (0.6594847378018923, 0.7694511628987143))
# --> Test accuracy(confidence interval 0.95):(0.7368421052631577, (0.6498923153224472, 0.8237918952038683))
# --> Test f1(confidence interval 0.95):(0.6901817137111255, (0.5765340457596685, 0.8038293816625824))
# --> Test recall(confidence interval 0.95):(0.8782142857142858, (0.7902616156930842, 0.9661669557354875))
# --> Test precision(confidence interval 0.95):(0.5674747474747475, (0.3755825662274258, 0.7593669287220691))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.8, 'gamma': 2, 'learning_rate': 0.2, 'max_depth': None, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.889145854145854
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8482176157176158, (0.7807714810932344, 0.9156637503419972))
# --> Test balanced_accuracy(confidence interval 0.95):(0.833525698158051, (0.7924202983970783, 0.8746310979190237))
# --> Test accuracy(confidence interval 0.95):(0.7684210526315789, (0.6992244598821425, 0.8376176453810152))
# --> Test f1(confidence interval 0.95):(0.7422227119285942, (0.7073112548872451, 0.7771341689699434))
# --> Test recall(confidence interval 0.95):(0.8091666666666667, (0.6911237452458876, 0.9272095880874458))
# --> Test precision(confidence interval 0.95):(0.7985669885669886, (0.6958322397742546, 0.9013017373597226))
# ----------------Training dataset_20_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 272
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 11, 'weights': 'distance'}
# Best CV auc_roc: 0.7863888888888889
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8292156862745097, (0.7368524838558212, 0.9215788886931982))
# --> Test balanced_accuracy(confidence interval 0.95):(0.841890264877881, (0.7867753720722696, 0.8970051576834924))
# --> Test accuracy(confidence interval 0.95):(0.7947368421052631, (0.7462927241780205, 0.8431809600325056))
# --> Test f1(confidence interval 0.95):(0.11857142857142858, (-0.022708454670308797, 0.25985131181316595))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.225, (-0.07246864939927253, 0.5224686493992725))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.7503654970760234
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.6608525910364146, (0.5176142280897162, 0.8040909539831129))
# --> Test balanced_accuracy(confidence interval 0.95):(0.5798232323232324, (0.48692719272511775, 0.6727192719213471))
# --> Test accuracy(confidence interval 0.95):(0.531578947368421, (0.4715216672917792, 0.591636227445063))
# --> Test f1(confidence interval 0.95):(0.4153121001805212, (0.28342857812671507, 0.5471956222343274))
# --> Test recall(confidence interval 0.95):(0.3311111111111111, (0.25080987501882707, 0.4114123472033951))
# --> Test precision(confidence interval 0.95):(0.5833333333333333, (0.40339354737147526, 0.7632731192951913))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9158625730994153
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9117647058823529, (0.777226227451498, 1.0463031843132078))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9452130632954935, (0.9217342627711137, 0.9686918638198733))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842106, (0.879415766904747, 0.9521631804636742))
# --> Test f1(confidence interval 0.95):(0.6128571428571428, (0.33525874857642324, 0.8904555371378623))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.5466666666666666, (0.32734239242407503, 0.7659909409092582))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9200292397660818
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8565288388082506, (0.7450960275628165, 0.9679616500536847))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9273758963774444, (0.8890020827518972, 0.9657497100029917))
# --> Test accuracy(confidence interval 0.95):(0.8789473684210526, (0.8352917038769282, 0.922603032965177))
# --> Test f1(confidence interval 0.95):(0.66, (0.4524871210980038, 0.8675128789019962))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.5589285714285713, (0.3076864024622805, 0.8101707403948621))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 400}
# Best CV auc_roc: 0.9338596491228071
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9771428571428572, (0.949338488576002, 1.0049472257097123))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8262426900584796, (0.7735730243430267, 0.8789123557739326))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684211, (0.7363302247266952, 0.926827670010147))
# --> Test f1(confidence interval 0.95):(0.44523809523809527, (0.21841760863596507, 0.6720585818402255))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.2333333333333333, (-0.011330555285495064, 0.47799722195216165))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.01, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 500, 'subsample': 0.6}
# Best CV auc_roc: 0.7915058479532164
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7100775694893342, (0.5819271422569593, 0.8382279967217091))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8128740970072238, (0.6508095710083284, 0.9749386230061192))
# --> Test accuracy(confidence interval 0.95):(0.8315789473684211, (0.7526028786776126, 0.9105550160592296))
# --> Test f1(confidence interval 0.95):(0.27666666666666667, (0.014477544297401168, 0.5388557890359322))
# --> Test recall(confidence interval 0.95):(0.8333333333333333, (0.5757754103170022, 1.0908912563496642))
# --> Test precision(confidence interval 0.95):(0.275952380952381, (0.05823704309564162, 0.4936677188091204))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 1.0, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': 10, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9318713450292397
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9202962723550959, (0.860322988322678, 0.9802695563875139))
# --> Test balanced_accuracy(confidence interval 0.95):(0.901078431372549, (0.8145457191816715, 0.9876111435634264))
# --> Test accuracy(confidence interval 0.95):(0.9315789473684208, (0.8812218305822412, 0.9819360641546004))
# --> Test f1(confidence interval 0.95):(0.5757142857142856, (0.33270836216883787, 0.8187202092597334))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.61, (0.3928905212419942, 0.8271094787580058))
# ----------------Training dataset_21_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 214
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8620286098310291
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8322610586471475, (0.760903675907547, 0.903618441386748))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7418615398527925, (0.681446969451755, 0.8022761102538299))
# --> Test accuracy(confidence interval 0.95):(0.7736842105263158, (0.726558547359597, 0.8208098736930345))
# --> Test f1(confidence interval 0.95):(0.6271193682238934, (0.5368234349828512, 0.7174153014649355))
# --> Test recall(confidence interval 0.95):(0.8281254856254856, (0.7632985029351378, 0.8929524683158334))
# --> Test precision(confidence interval 0.95):(0.4520779220779221, (0.33579307115198564, 0.5683627730038585))
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.01, 'loss': 'log', 'penalty': 'l1'}
# Best CV auc_roc: 0.8014468125960063
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7988145204468734, (0.742497505556536, 0.8551315353372108))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6510697806964127, (0.5996421179406118, 0.7024974434522137))
# --> Test accuracy(confidence interval 0.95):(0.636842105263158, (0.5787850765877359, 0.69489913393858))
# --> Test f1(confidence interval 0.95):(0.5515096553773023, (0.5032759502297041, 0.5997433605249006))
# --> Test recall(confidence interval 0.95):(0.4602762588288904, (0.39316714714033874, 0.527385370517442))
# --> Test precision(confidence interval 0.95):(0.737336389101095, (0.635992712562305, 0.838680065639885))
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'penalty': 'l2'}
# Best CV auc_roc: 0.9189847350230413
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8989459548474397, (0.8762378674489799, 0.9216540422458994))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8490687746717726, (0.7760832138431868, 0.9220543355003583))
# --> Test accuracy(confidence interval 0.95):(0.8657894736842107, (0.820149460751717, 0.9114294866167043))
# --> Test f1(confidence interval 0.95):(0.7199886828147698, (0.6327429303166504, 0.8072344353128892))
# --> Test recall(confidence interval 0.95):(0.7699132730015084, (0.6585362908803516, 0.8812902551226651))
# --> Test precision(confidence interval 0.95):(0.7041746411483254, (0.6076317005816132, 0.8007175817150376))
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# Best CV auc_roc: 0.8170559715821811
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7343408256131472, (0.6887738803218767, 0.7799077709044177))
# --> Test balanced_accuracy(confidence interval 0.95):(0.668421052631579, (0.5978719555615266, 0.7389701497016314))
# --> Test accuracy(confidence interval 0.95):(0.6894736842105263, (0.6341961345497023, 0.7447512338713504))
# --> Test f1(confidence interval 0.95):(0.0, (0.0, 0.0))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.0, (0.0, 0.0))
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# Best CV auc_roc: 0.9368418778801842
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9372798041677353, (0.9018597964669375, 0.972699811868533))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8592171963468814, (0.8070577853415546, 0.9113766073522083))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421053, (0.7975757680311616, 0.9182137056530489))
# --> Test f1(confidence interval 0.95):(0.7884311556964396, (0.7451304779738409, 0.8317318334190383))
# --> Test recall(confidence interval 0.95):(0.6931462328521152, (0.6006229217911226, 0.7856695439131077))
# --> Test precision(confidence interval 0.95):(0.7317249417249416, (0.6398299669828851, 0.8236199164669982))
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 400, 'subsample': 1.0}
# Best CV auc_roc: 0.9287255184331796
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9276576293150264, (0.8936444471804299, 0.9616708114496229))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8457962065420835, (0.7976822801744102, 0.8939101329097568))
# --> Test accuracy(confidence interval 0.95):(0.8184210526315789, (0.7763734641351587, 0.8604686411279991))
# --> Test f1(confidence interval 0.95):(0.7288961520511863, (0.6737625082332813, 0.7840297958690913))
# --> Test recall(confidence interval 0.95):(0.7707400932400933, (0.6972364853524903, 0.8442437011276963))
# --> Test precision(confidence interval 0.95):(0.6624666999666999, (0.5612110292075059, 0.763722370725894))
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 0.6, 'gamma': 2, 'learning_rate': 0.2, 'max_depth': 15, 'min_child_weight': 1, 'subsample': 1.0}
# Best CV auc_roc: 0.9352049731182795
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9042600316731886, (0.8672639755379536, 0.9412560878084235))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8770641219624148, (0.8327097002330993, 0.9214185436917303))
# --> Test accuracy(confidence interval 0.95):(0.855263157894737, (0.8330774684575575, 0.8774488473319164))
# --> Test f1(confidence interval 0.95):(0.7385503822914645, (0.6607494390803955, 0.8163513255025335))
# --> Test recall(confidence interval 0.95):(0.791268568033274, (0.6925402922446446, 0.8899968438219032))
# --> Test precision(confidence interval 0.95):(0.7396103896103897, (0.6287791953300931, 0.8504415838906864))
