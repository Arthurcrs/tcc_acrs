# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
sys.path.append('../src/')
from TrainModels import *

# %%
datasets_full = ['dataset_1_', 'dataset_2_', 'dataset_3_', 'dataset_7_']
datasets_gwas = ['dataset_19_', 'dataset_20_', 'dataset_21_']

# %%
feature_selection = {"method": "RFE" , "estimator": "SVC" }
# train_models = ["KNN","SGDClassifier","LogisticRegression","SVC","RandomForestClassifier","GBTC","XGB","MLPClassifier"]
# train_models = ["all"]

# %%
train_models = ["KNN"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'hamming', 'n_neighbors': 3, 'weights': 'distance'}
# Best CV auc_roc: 0.8884565434565435
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9223071373071372, (0.8893196506836747, 0.9552946239305997))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8136471861471861, (0.738008636685897, 0.8892857356084752))
# --> Test accuracy(confidence interval 0.95):(0.7999999999999999, (0.7537174400192194, 0.8462825599807805))
# --> Test f1(confidence interval 0.95):(0.7235108828220282, (0.6350590750387338, 0.8119626906053227))
# --> Test recall(confidence interval 0.95):(0.8421428571428573, (0.7508773243103357, 0.9334083899753789))
# --> Test precision(confidence interval 0.95):(0.7222871572871573, (0.6228227353602381, 0.8217515792140765))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/1073640720.py in <module>
#       1 train_models = ["KNN"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_KNN.pkl'

# %%
train_models = ["SGDClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********Stochastic Gradient Descent Classifier*********
# Performed GridSearchCV 10
# Best CV params {'alpha': 0.001, 'loss': 'log', 'penalty': 'l2'}
# Best CV auc_roc: 0.9600549450549452
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9408233433233433, (0.8977970582237983, 0.9838496284228883))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9493657731157732, (0.914578929360343, 0.9841526168712034))
# --> Test accuracy(confidence interval 0.95):(0.9578947368421054, (0.9232964404673871, 0.9924930332168236))
# --> Test f1(confidence interval 0.95):(0.9150782550782551, (0.84411701730682, 0.9860394928496903))
# --> Test recall(confidence interval 0.95):(0.9436363636363636, (0.8717533626495172, 1.0155193646232101))
# --> Test precision(confidence interval 0.95):(0.8774999999999998, (0.8217945383697892, 0.9332054616302105))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/1726060269.py in <module>
#       1 train_models = ["SGDClassifier"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_SGDC.pkl'

# %%
train_models = ["LogisticRegression"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********Logistic Regression*********
# Performed GridSearchCV 10
# Best CV params {'C': 10, 'penalty': 'l2'}
# Best CV auc_roc: 0.9659040959040958
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9411052836052836, (0.8829902963270164, 0.9992202708835507))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9244121156621155, (0.8935039300861031, 0.9553203012381278))
# --> Test accuracy(confidence interval 0.95):(0.9473684210526315, (0.9076814532852457, 0.9870553888200173))
# --> Test f1(confidence interval 0.95):(0.8844084879688596, (0.8518900040295023, 0.9169269719082169))
# --> Test recall(confidence interval 0.95):(0.9209920634920635, (0.8565687386595842, 0.9854153883245429))
# --> Test precision(confidence interval 0.95):(0.8497008547008548, (0.7691058027360151, 0.9302959066656944))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/3690290733.py in <module>
#       1 train_models = ["LogisticRegression"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_LR.pkl'

# %%
train_models = ["SVC"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********Support Vectors Classifier*********
# Performed GridSearchCV 10
# Best CV params {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# Best CV auc_roc: 0.9830969030969031
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9686363636363635, (0.9417486899847509, 0.9955240372879761))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9210302197802198, (0.8777775684267052, 0.9642828711337345))
# --> Test accuracy(confidence interval 0.95):(0.9526315789473685, (0.9196651075970258, 0.9855980502977112))
# --> Test f1(confidence interval 0.95):(0.9586347089443065, (0.9325430386345768, 0.9847263792540362))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.8607864357864358, (0.7848689896270953, 0.9367038819457763))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/924989423.py in <module>
#       1 train_models = ["SVC"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_SVC.pkl'

# %%
train_models = ["RandomForestClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********Random Forest*********
# Performed GridSearchCV 10
# Best CV params {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 50}
# Best CV auc_roc: 0.9477097902097903
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9227331002331003, (0.865790257512482, 0.9796759429537186))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9193706293706294, (0.8858098830391252, 0.9529313757021336))
# --> Test accuracy(confidence interval 0.95):(0.9157894736842106, (0.8715959367234037, 0.9599830106450175))
# --> Test f1(confidence interval 0.95):(0.9157686757686758, (0.8568263917041872, 0.9747109598331645))
# --> Test recall(confidence interval 0.95):(0.9050324675324676, (0.85046190585325, 0.9596030292116852))
# --> Test precision(confidence interval 0.95):(0.7748015873015872, (0.660090277429732, 0.8895128971734424))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/4213109459.py in <module>
#       1 train_models = ["RandomForestClassifier"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_RF.pkl'

# %%
train_models = ["GBTC"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********Gradient Boosting Classifier*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 20, 'n_estimators': 200, 'subsample': 1.0}
# Best CV auc_roc: 0.8827972027972028
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8735299422799423, (0.8008271274568026, 0.946232757103082))
# --> Test balanced_accuracy(confidence interval 0.95):(0.9100804342716108, (0.8725586003988463, 0.9476022681443753))
# --> Test accuracy(confidence interval 0.95):(0.868421052631579, (0.7866042725988713, 0.9502378326642866))
# --> Test f1(confidence interval 0.95):(0.8109735122119023, (0.7245324874806492, 0.8974145369431553))
# --> Test recall(confidence interval 0.95):(0.9242424242424242, (0.8424915201345146, 1.005993328350334))
# --> Test precision(confidence interval 0.95):(0.7541056166056166, (0.6559288738295446, 0.8522823593816886))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/1998766843.py in <module>
#       1 train_models = ["GBTC"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_GBTC.pkl'

# %%
train_models = ["XGB"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
#
# *********XGBoost*********
# Performed GridSearchCV 10
# Best CV params {'colsample_bytree': 1.0, 'gamma': 0.5, 'learning_rate': 0.2, 'max_depth': None, 'min_child_weight': 1, 'subsample': 0.8}
# Best CV auc_roc: 0.9186888111888113
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.875143745143745, (0.816452979947957, 0.9338345103395331))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8887247474747475, (0.8518747567604233, 0.9255747381890717))
# --> Test accuracy(confidence interval 0.95):(0.8894736842105264, (0.8378806261129249, 0.9410667423081279))
# --> Test f1(confidence interval 0.95):(0.8581279646752794, (0.7727219658525382, 0.9435339634980207))
# --> Test recall(confidence interval 0.95):(0.9279761904761905, (0.8550357778220394, 1.0009166031303416))
# --> Test precision(confidence interval 0.95):(0.7962626262626262, (0.7102804340277975, 0.882244818497455))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10235/1312168113.py in <module>
#       1 train_models = ["XGB"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     181
#     182             for model in self.models:
# --> 183                 self.save_trained_models(dataset_name, self.models[model], model)
#     184
#     185             self.models = {}
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in save_trained_models(self, dataset, model, model_name)
#     488     def save_trained_models(self, dataset, model, model_name):
#     489         path = '../models/{}/{}.pkl'
# --> 490         jb.dump(model, path.format(dataset, dataset + model_name))
#     491
#     492     def main(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     479             NumpyPickler(f, protocol=protocol).dump(value)
#     480     elif is_filename:
# --> 481         with open(filename, 'wb') as f:
#     482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/dataset_1_/dataset_1_XGB.pkl'

# %%
train_models = ["MLPClassifier"]
TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
TM.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 207
# Perform Multi-layer Perceptron training.
#
# *********Multi-layer Perceptron*********
# Performed GridSearchCV 10
# Best CV params {'learning_rate': 'constant', 'solver': 'lbfgs', 'warm_start': True}
# Best CV auc_roc: nan
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.6394660894660895, (0.5539212451218156, 0.7250109338103634))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10235/4155552867.py in <module>
#       1 train_models = ["MLPClassifier"]
#       2 TM = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
# ----> 3 TM.main()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in main(self)
#     494
#     495         if self.dataset_full:
# --> 496             self.perform_train_full()
#     497         if self.datasets_gwas:
#     498             self.perform_train_gwas()
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in perform_train_full(self)
#     178                 self.perform_XGB(dataset, metadata, dataset_name)
#     179             if "MLPClassifier" in self.train_models or "all" in self.train_models:
# --> 180                 self.train_MLPC(dataset,metadata,dataset_name)
#     181
#     182             for model in self.models:
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in train_MLPC(self, dataset, metadata, name)
#     340         model_info = ["Multi-layer Perceptron", x_test, y_test, "MLP"]
#     341
# --> 342         self.print_performance_metrics(grid, model_info[0], model_info[1],
#     343                                        model_info[2], name, model_info[3])
#     344
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in print_performance_metrics(self, grid, name, x_test, y_test, dataset, short_name, xgboost)
#     141             print("--> Test {}(confidence interval 0.95):{}"
#     142                   .format(metric,
# --> 143                           self.mean_confidence_interval(grid.best_estimator_,
#     144                                                         x_test, y_test,
#     145                                                         scoring=metric,
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in mean_confidence_interval(self, grid, x_test, y_test, xgboost, confidence, scoring)
#      97                 y_pred = grid.predict(x_sample_array)
#      98
# ---> 99             score = self.calculate_metrics(y_pred, y_sample_array, scoring)
#     100             score_array.append(score)
#     101
#
# ~/Documents/tcc_acrs/notebooks/../src/TrainModels.py in calculate_metrics(x, y, scoring)
#     119                 return 1
#     120         elif scoring == 'balanced_accuracy':
# --> 121             return balanced_accuracy_score(x, y)
#     122         elif scoring == 'f1':
#     123             return f1_score(x, y)
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py in balanced_accuracy_score(y_true, y_pred, sample_weight, adjusted)
#    1947
#    1948     """
# -> 1949     C = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
#    1950     with np.errstate(divide="ignore", invalid="ignore"):
#    1951         per_class = np.diag(C) / C.sum(axis=1)
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     300
#     301     """
# --> 302     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     303     if y_type not in ("binary", "multiclass"):
#     304         raise ValueError("%s is not supported" % y_type)
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets
