# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
sys.path.append('../src/')
from PredictPRInKP import *

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import * 

datasets_full = ['dataset_1_', 'dataset_2_','dataset_3_','dataset_7_']
datasets_gwas = []

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "Select From Model", "SVC")
PR.main()

print("finished model training")
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 623
# Perform Multi-layer Perceptron training.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_449885/3431898998.py in <module>
#       1 PR = PredictPRinKP(datasets_full, datasets_gwas, "Select From Model", "SVC")
# ----> 2 PR.main()
#       3
#       4 print("finished model training")
#
# ~/Insync/arthcrs@gmail.com/Google-Drive/College/TCC/Repositories/predicting-PR-in-KB/Notebooks/../src/PredictPRInKP.py in main(self)
#     500
#     501         if self.dataset_full:
# --> 502             self.perform_train_full()
#     503         if self.datasets_gwas:
# ...

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "Select From Model", "Random Forest Classifier")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 616
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8193406593406592
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8107911532911534, (0.7280882687669072, 0.8934940378153995))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7070183982683983, (0.6350491490783051, 0.7789876474584915))
# --> Test accuracy(confidence interval 0.95):(0.6631578947368422, (0.5833880767685099, 0.7429277127051744))
# --> Test f1(confidence interval 0.95):(0.6142319591313399, (0.5021614606537315, 0.7263024576089483))
# ...

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "Select From Model", "Logistic Regression")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Logistic Regression
# ---- Completed feature selection ----
# Number of features selected: 792
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.829875124875125
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.8308594183594185, (0.7278305024203388, 0.9338883342984982))
# --> Test balanced_accuracy(confidence interval 0.95):(0.6941697191697191, (0.5778652790051186, 0.8104741593343197))
# --> Test accuracy(confidence interval 0.95):(0.6947368421052632, (0.6241877450352108, 0.7652859391753156))
# --> Test f1(confidence interval 0.95):(0.7158641590607535, (0.6558559847770905, 0.7758723333444165))
# ...
