# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import *

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import * 

datasets_full = ['dataset_1_']
datasets_gwas = ['dataset_19_']

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "SVC")
PR.main()

print("finished model training")
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 299
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 11, 'weights': 'distance'}
# Best CV auc_roc: 0.8638561438561438
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9053030303030303, (0.8683064249759525, 0.9422996356301081))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7991902541902541, (0.7409622261071421, 0.8574182822733661))
# --> Test accuracy(confidence interval 0.95):(0.7947368421052632, (0.7249735192295585, 0.8645001649809678))
# --> Test f1(confidence interval 0.95):(0.698, (0.5538991275575751, 0.8421008724424248))
# ...

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "Random Forest Classifier")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 238
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 7, 'weights': 'distance'}
# Best CV auc_roc: 0.8244805194805196
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.884388111888112, (0.833101395571194, 0.9356748282050299))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7312820512820513, (0.6574753140252763, 0.8050887885388263))
# --> Test accuracy(confidence interval 0.95):(0.7105263157894737, (0.6213409480244861, 0.7997116835544612))
# --> Test f1(confidence interval 0.95):(0.540521978021978, (0.40311903151026623, 0.6779249245336898))
# ...

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "Logistic Regression")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Logistic Regression
# ---- Completed feature selection ----
# Number of features selected: 211
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'hamming', 'n_neighbors': 5, 'weights': 'distance'}
# Best CV auc_roc: 0.877047952047952
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.9344334831834832, (0.8970687467894484, 0.971798219577518))
# --> Test balanced_accuracy(confidence interval 0.95):(0.7250948357198357, (0.6688413062059547, 0.7813483652337166))
# --> Test accuracy(confidence interval 0.95):(0.7684210526315789, (0.677573431026034, 0.8592686742371238))
# --> Test f1(confidence interval 0.95):(0.6887495700034398, (0.5524170455740747, 0.825082094432805))
# ...
