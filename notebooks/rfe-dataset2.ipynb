# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import *

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import * 

datasets_full = ['dataset_2_']
datasets_gwas = []

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "SVC")
PR.main()

print("finished model training")
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_2_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 204
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 19, 'weights': 'distance'}
# Best CV auc_roc: 0.8462719298245615
# Best estimator metrics:
# error roc_auc
# --> Test roc_auc(confidence interval 0.95):(0.9152281297134239, (0.8385511458012201, 0.9919051136256277))
# --> Test balanced_accuracy(confidence interval 0.95):(0.8924707602339181, (0.8393749542967868, 0.9455665661710495))
# --> Test accuracy(confidence interval 0.95):(0.9052631578947368, (0.8497014030203967, 0.9608249127690769))
# --> Test f1(confidence interval 0.95):(0.225, (9.721249455174608e-05, 0.44990278750544827))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.3261904761904762, (0.13406987528111408, 0.5183110770998383))
# finished model training

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "Random Forest Classifier")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_2_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Random Forest Classifier
# ---- Completed feature selection ----
# Number of features selected: 363
#
# *********K-nearst neighbors*********
# Performed GridSearchCV 10
# Best CV params {'metric': 'jaccard', 'n_neighbors': 13, 'weights': 'distance'}
# Best CV auc_roc: 0.7680116959064327
# Best estimator metrics:
# --> Test roc_auc(confidence interval 0.95):(0.7500595238095238, (0.6115716238830411, 0.8885474237360065))
# --> Test balanced_accuracy(confidence interval 0.95):(0.892690058479532, (0.8433486083162045, 0.9420315086428594))
# --> Test accuracy(confidence interval 0.95):(0.8578947368421053, (0.8016287491119967, 0.9141607245722139))
# --> Test f1(confidence interval 0.95):(0.5792424242424242, (0.3334378489212263, 0.8250469995636222))
# --> Test recall(confidence interval 0.95):(1.0, (1.0, 1.0))
# --> Test precision(confidence interval 0.95):(0.35261904761904767, (0.19695280758474723, 0.5082852876533481))

# %%
PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "Logistic Regression")
PR.main()
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_2_----------------
# ---- Performing Feature Selection ----
# Method: Recursive Feature Selection with CV
# Estimator: Logistic Regression
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_345383/572324373.py in <module>
#       1 PR = PredictPRinKP(datasets_full, datasets_gwas, "RFE", "Logistic Regression")
# ----> 2 PR.main()
#
# ~/Insync/arthcrs@gmail.com/Google-Drive/College/TCC/Repositories/acrs_tcc/src/PredictPRInKP.py in main(self)
#     472         jb.dump(model, '../models/{}/{}.pkl'.format(dataset,
#     473                                                     dataset + model_name))
# --> 474
#     475     def main(self):
#     476         """Main PredictPRinKP method."""
#
# ~/Insync/arthcrs@gmail.com/Google-Drive/College/TCC/Repositories/acrs_tcc/src/PredictPRInKP.py in perform_train_full(self)
#     171             name = i
#     172
# --> 173             self.perform_feature_selection(dataset, metadata,dataset_name=name)
#     174             self.train_KNN(dataset, metadata, name)
#     175             # self.train_SGDClassifier(dataset, metadata, name)
#
# ~/Insync/arthcrs@gmail.com/Google-Drive/College/TCC/Repositories/acrs_tcc/src/PredictPRInKP.py in perform_feature_selection(self, dataset, metadata, dataset_name, gwas)
#     254
#     255         if self.fs_method == "Select From Model" :
# --> 256             print("Method: Select From Model")
#     257             X_train, X_test, y_train, y_test = \
#     258             train_test_split(X,y,test_size=0.25, random_state=self.SEED,
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in fit(self, X, y, groups)
#     708             func = delayed(_rfe_single_fit)
#     709
# --> 710         scores = parallel(
#     711             func(rfe, self.estimator, X, y, train, test, scorer)
#     712             for train, test in cv.split(X, y, groups)
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in <genexpr>(.0)
#     709
#     710         scores = parallel(
# --> 711             func(rfe, self.estimator, X, y, train, test, scorer)
#     712             for train, test in cv.split(X, y, groups)
#     713         )
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in _rfe_single_fit(rfe, estimator, X, y, train, test, scorer)
#      35     X_train, y_train = _safe_split(estimator, X, y, train)
#      36     X_test, y_test = _safe_split(estimator, X, y, test, train)
# ---> 37     return rfe._fit(
#      38         X_train,
#      39         y_train,
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_rfe.py in _fit(self, X, y, step_score, **fit_params)
#     281                 print("Fitting estimator with %d features." % np.sum(support_))
#     282
# --> 283             estimator.fit(X[:, features], y, **fit_params)
#     284
#     285             # Get importance and rank them
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1587         else:
#    1588             prefer = "processes"
# -> 1589         fold_coefs_ = Parallel(
#    1590             n_jobs=self.n_jobs,
#    1591             verbose=self.verbose,
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     207     def __call__(self, *args, **kwargs):
#     208         with config_context(**self.config):
# --> 209             return self.function(*args, **kwargs)
#     210
#     211
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     804                 np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     805             ]
# --> 806             opt_res = optimize.minimize(
#     807                 func,
#     808                 w0,
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     621                                   **options)
#     622     elif meth == 'l-bfgs-b':
# --> 623         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                                 callback=callback, **options)
#     625     elif meth == 'tnc':
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     265         if not np.array_equal(x, self.x):
#     266             self._update_x_impl(x)
# --> 267         self._update_fun()
#     268         self._update_grad()
#     269         return self.f, self.g
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     125     z0 = sample_weight * (z - 1) * y
#     126
# --> 127     grad[:n_features] = safe_sparse_dot(X.T, z0) + alpha * w
#     128
#     129     # Case where we fit the intercept.
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     154
#     155     if (
# --> 156         sparse.issparse(a)
#     157         and sparse.issparse(b)
#     158         and dense_output
#
# ~/.local/lib/python3.8/site-packages/scipy/sparse/base.py in isspmatrix(x)
#    1203
#    1204
# -> 1205 def isspmatrix(x):
#    1206     """Is x of a sparse matrix type?
#    1207
#
# KeyboardInterrupt:
